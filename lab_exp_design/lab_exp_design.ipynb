# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Chengyang"
ca1_name = "Talia"
ca2_name = "Kirthi"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Jacky Zhang"
partner1_netid = "jackyz2"
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(✏️Edit this cell to add your group's question.✏️)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`. Don't forget to import pandas as well!

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")
df
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 1                Prof. Wade  L1, L2
# 2                    Andrew     Y05
# 3                  Annabel      Y05
# 4                    Ayden      Y14
# ..                      ...     ...
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
# 962                   Nyssa     Y23
# 963                  maddax      Y2
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# ..                                                 ...
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# ..                                                 ...
# 960                                              Heads
# 961                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# ..                                  ...                    ...
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# ..                             ...                                  ...
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# ..                                        ...
# 960                            Morning Person
# 961                            Morning Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# ..                                               ...  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 2                                                  Y05
# 3                                                  Y05
# 4                                                  Y14
# ..                                                 ...
# 960                                                Y22
# 961                                                Y09
# 962                                                Y23
# 963                                                 Y2
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# ..                                                 ...
# 960                                             strong
# 961                                             strong
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# ..                                                 ...
# 960                                                las
# 961                                                 CS
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# ..                                              ...
# 960                                              CS
# 961                                              CS
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# ..                                    ...                                ...
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# ..                                     ...                          ...
# 960                                   Snap                         ini
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# ..                                                 ...
# 960                                       apex legends
# 961                                     Clash of clans
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# ..                                    ...
# 960                                europe
# 961                               Iceland
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [965 rows x 180 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  'What is your first name you want us to use for you?',
#  'What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = 'Do you prefer green or red?'
analysis_column
# Out:
# 'Do you prefer green or red?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 965), "You have not loaded the correct Hello dataset"
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Do you prefer green or red?
# 0                         Green
# 1                         Green
# 2                         Green
# 3                           Red
# 4                         Green
# ..                          ...
# 960                         Red
# 961                       Green
# 962                       Green
# 963                         Red
# 964                       Green
#
# [965 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df["Do you prefer green or red?"]== "Red"]
df1
# Out:
#                        Name Section  \
# 3                  Annabel      Y05
# 5                      Sens     Y30
# 7                Joseph Kim     Y16
# 10                  Aaliyah     Y13
# 12                     Ryan     Y30
# ..                      ...     ...
# 946                    Abby       Y
# 947                Maximoff     Y33
# 949                Vihaansh     Y08
# 960  Mohammed Fatheen Ahmed     Y22
# 963                  maddax      Y2
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 5                       NetID ends with an even number
# 7                       NetID ends with an even number
# 10                      NetID ends with an even number
# 12                      NetID ends with an even number
# ..                                                 ...
# 946                     NetID ends with an even number
# 947                      NetID ends with an odd number
# 949                      NetID ends with an odd number
# 960                      NetID ends with an odd number
# 963                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 5                                                Heads
# 7                                                Heads
# 10                                               Heads
# 12                                               Heads
# ..                                                 ...
# 946                                              Heads
# 947                                              Tails
# 949                                              Heads
# 960                                              Heads
# 963                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 5                                 Tacos                    1.0
# 7                                Donuts                    1.0
# 10                               Donuts                    1.0
# 12                               Donuts                    0.0
# ..                                  ...                    ...
# 946                              Donuts                    1.0
# 947                               Tacos                    0.0
# 949                               Tacos                    1.0
# 960                              Donuts                    0.0
# 963                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 5              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 10             Freshman in College                         Night Person
# 12             Freshman in College                         Night Person
# ..                             ...                                  ...
# 946            Freshman in College                         Night Person
# 947                 Not a Freshman                         Night Person
# 949                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 963            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 5                              Morning Person
# 7                            Afternoon Person
# 10                           Afternoon Person
# 12                           Afternoon Person
# ..                                        ...
# 946                          Afternoon Person
# 947                          Afternoon Person
# 949                          Afternoon Person
# 960                            Morning Person
# 963                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 5                                           Illinois  ...
# 7                                           Illinois  ...
# 10                                          Illinois  ...
# 12                                          Illinois  ...
# ..                                               ...  ...
# 946                                         Illinois  ...
# 947                                         Illinois  ...
# 949                                     Out-of-state  ...
# 960                                         Illinois  ...
# 963                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 3                                                  Y05
# 5                                                  Y30
# 7                                                  Y16
# 10                                                 Y13
# 12                                                 Y30
# ..                                                 ...
# 946                                                  Y
# 947                                                Y33
# 949                                                Y08
# 960                                                Y22
# 963                                                 Y2
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 5                                             Moderate
# 7                                                 Mild
# 10                                             Extreme
# 12                                            Moderate
# ..                                                 ...
# 946                                             strong
# 947                                             Strong
# 949                                            Extreme
# 960                                             strong
# 963                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 5                                     Grainger and LAS
# 7                                                  LAS
# 10                                             iSchool
# 12                                                 LAS
# ..                                                 ...
# 946                         Data science and Business
# 947                                                LAS
# 949                               Computer Engineering
# 960                                                las
# 963                          finance with data science
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 5                                               ECE
# 7                                  Computer Science
# 10                                 Computer Science
# 12                                          Physics
# ..                                              ...
# 946                               Computer science
# 947                            chemical engineering
# 949                          Electrical Engineering
# 960                                              CS
# 963                                         general
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 5                                Shoegaze                        Fiona Apple
# 7                              soundtrack             Ski Mask the Slump God
# 10                                    Pop                       Taylor Swift
# 12                                   Rock               Two Door Cinema Club
# ..                                    ...                                ...
# 946    anything besides rock and country                     Kendrick Lamar
# 947       hip-hop, r&b, rock, heavy metal                              JIHYO
# 949                                  Rock                             Eminem
# 960                                   rap                              Drake
# 963                                   rap                       lil uzi vert
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 5                                  Twitter                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 10                                  TikTok                          INI
# 12                                 youtube                  **silence**
# ..                                     ...                          ...
# 946                             Instagram                           INI
# 947                                Twitter                           🧡💙
# 949                              Instagram                        I-N-I
# 960                                   Snap                         ini
# 963                               snapchat                          ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 5                                            Fall Guys
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 10                                    Capture the Flag
# 12                                          Overcooked
# ..                                                 ...
# 946                                        Basketball
# 947                                               OSU!
# 949                                             Soccer
# 960                                       apex legends
# 963                                        quiet game
#
#     What is your dream vacation location?
# 3                                 Greece
# 5                                      PR
# 7                                 Nowhere
# 10                                  Spain
# 12              Grand Teton National Park
# ..                                    ...
# 946              Iceland during the fall
# 947                        Cancún, Mexico
# 949                                Norway
# 960                                europe
# 963                    middle of nowhere
#
# [405 rows x 180 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df["Do you prefer green or red?"] == "Green"]
df2
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 2         Andrew     Y05
# 4         Ayden      Y14
# 6          Suvan     Y22
# ..           ...     ...
# 956      Fabian      Y11
# 959         Zoe      Y19
# 961        Peter     Y09
# 962        Nyssa     Y23
# 964   CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 956                      NetID ends with an odd number
# 959                     NetID ends with an even number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 4                                                Heads
# 6                                                Heads
# ..                                                 ...
# 956                                              Tails
# 959                                              Heads
# 961                                              Heads
# 962                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 956                               Tacos                    0.0
# 959                               Tacos                    1.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 956                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 956                          Afternoon Person
# 959                          Afternoon Person
# 961                            Morning Person
# 962                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 956                                         Illinois  ...
# 959                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 2                                                  Y05
# 4                                                  Y14
# 6                                                  Y22
# ..                                                 ...
# 956                                                Y11
# 959                                                Y19
# 961                                                Y09
# 962                                                Y23
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 4                                               Strong
# 6                                               Strong
# ..                                                 ...
# 956                                           Extreme
# 959                                          Moderate
# 961                                             strong
# 962                                               mild
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 4                                                 Gies
# 6                      Statistics and Computer Science
# ..                                                 ...
# 956                                                 IS
# 959                              School of Information
# 961                                                 CS
# 962                                                las
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 4                                   Any engineering
# 6                              Computer Engineering
# ..                                              ...
# 956                               Computer science
# 959                          Molecular engineering
# 961                                              CS
# 962                                             ece
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 956                                   Rap                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 956                                      X                        I-N-I
# 959                                Tiktok                        I-N-I!
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 4                                           Basketball
# 6                                         20 questions
# ..                                                 ...
# 956                                          Valorant
# 959                                   Street Fighters
# 961                                     Clash of clans
# 962                                         code names
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 4                              Australia
# 6                             Switzerland
# ..                                    ...
# 956                                Greece
# 959                               Greece
# 961                               Iceland
# 962                                greece
# 964                                 Korea
#
# [548 rows x 180 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# ✏️(*The percentage of people choose Red is 405/945 = 41.97% ;
#
# The perventage of people choose Green is 548/945 = 56.79% ✏️)*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# ✏️(*Yes, the answers is surprise me. Because people who like green are much more than red.✏️)*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# ✏️(*No, people who like green are 56.79% - 41.97% = 14.82% more than red. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#             Name Section  \
# 927      Shreyas     Y36
# 678     Brianna      Y24
# 426        Arnav     Y14
# 151       joules     Y05
# 287         Erik     Y49
# ..           ...     ...
# 0    Prof. Karle  L1, L2
# 720        Anish     Y17
# 258          Jon     Y17
# 394        Renee     Y27
# 267         Said    Y15
#
#     Does your NetID ending with odd number or even number?  \
# 927                      NetID ends with an odd number
# 678                     NetID ends with an even number
# 426                      NetID ends with an odd number
# 151                     NetID ends with an even number
# 287                     NetID ends with an even number
# ..                                                 ...
# 0                        NetID ends with an odd number
# 720                      NetID ends with an odd number
# 258                      NetID ends with an odd number
# 394                      NetID ends with an odd number
# 267                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 927                                              Heads
# 678                                              Heads
# 426                                              Heads
# 151                                              Heads
# 287                                              Heads
# ..                                                 ...
# 0                                                Heads
# 720                                              Heads
# 258                                              Heads
# 394                                              Heads
# 267                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 927                              Donuts                    1.0
# 678                               Tacos                    1.0
# 426                               Tacos                    1.0
# 151                              Donuts                    0.0
# 287                              Donuts                    0.0
# ..                                  ...                    ...
# 0                                 Tacos                    0.0
# 720                              Donuts                    0.0
# 258                              Donuts                    0.0
# 394                                 NaN                    0.0
# 267                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 927                 Not a Freshman                         Night Person
# 678            Freshman in College                         Night Person
# 426                 Not a Freshman                         Night Person
# 151            Freshman in College                         Night Person
# 287            Freshman in College                         Night Person
# ..                             ...                                  ...
# 0                   Not a Freshman                         Night Person
# 720                 Not a Freshman                       Morning Person
# 258            Freshman in College                       Morning Person
# 394            Freshman in College                       Morning Person
# 267                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 927                          Afternoon Person
# 678                          Afternoon Person
# 426                          Afternoon Person
# 151                          Afternoon Person
# 287                          Afternoon Person
# ..                                        ...
# 0                            Afternoon Person
# 720                            Morning Person
# 258                            Morning Person
# 394                            Morning Person
# 267                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 927                                         Illinois  ...
# 678                                         Illinois  ...
# 426                                     Out-of-state  ...
# 151                                         Illinois  ...
# 287                                         Illinois  ...
# ..                                               ...  ...
# 0                                           Illinois  ...
# 720                                         Illinois  ...
# 258                                         Illinois  ...
# 394                                     Out-of-state  ...
# 267                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 927                                                Y36
# 678                                                Y24
# 426                                                Y14
# 151                                                Y05
# 287                                                Y49
# ..                                                 ...
# 0                                               L1, L2
# 720                                                Y17
# 258                                                Y17
# 394                                                Y27
# 267                                               Y15
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 927                                            extreme
# 678                                             strong
# 426                                             Strong
# 151                                             strong
# 287                                          moderate
# ..                                                 ...
# 0                                             moderate
# 720                                          Moderate
# 258                                                NaN
# 394                                           Moderate
# 267                                           moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 927                                                LAS
# 678                             Finance + Data Science
# 426                             Finance + Data Science
# 151                                                las
# 287                                                LAS
# ..                                                 ...
# 0                                           Statistics
# 720                              Information Sciences
# 258                                               Gies
# 394                              Operations Management
# 267                                              Media
#
#     What do you think is the hardest major at UIUC?  \
# 927                                              CS
# 678                                    Engineering
# 426                                Computer science
# 151                                   aerospace/ece
# 287                                computer science
# ..                                              ...
# 0                             Anything in GRAINGER!
# 720                               Computer Science
# 258                                              Cs
# 394                                      pure maths
# 267                                         Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 927                                 r n b                            Weekend
# 678                                   Pop                       Lana del Rey
# 426                                   Pop                         The Weeknd
# 151                   electronic/shoegaze                               lush
# 287                               hip hop                          21 savage
# ..                                    ...                                ...
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 720                                  Pop                      Justin Bieber
# 258                               Coutnry                      Morgan wallen
# 394                                 Indie                   I don't have one
# 267                          Spanish Rock                               Mana
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 927                                tik tok                       I dont
# 678                                 TikTok                        I-N-I
# 426                              Instagram                        I-N-I
# 151                                twitter                illest mc nas
# 287                                tik tok                          INI
# ..                                     ...                          ...
# 0                                Instagram                        I-N-I
# 720                              Instagram                          INI
# 258                              Isntagram                         Ini
# 394                              Instagram                        I-N-I
# 267                               Snapchat                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 927                                             soccer
# 678                                          Minecraft
# 426                                               Fifa
# 151                                           valorant
# 287                                             hockey
# ..                                                 ...
# 0                                Any type of card game
# 720                                   Super Smash Bros
# 258                                         Basketball
# 394                                              Hades
# 267                                             Soccer
#
#     What is your dream vacation location?
# 927                             barcelona
# 678                                 Paris
# 426                                Monaco
# 151                                zurich
# 287                               Hawaii
# ..                                    ...
# 0                            The Maldives
# 720                     Honolulu, Hawaii
# 258                                 Aruba
# 394                               Denmark
# 267                                Mexico
#
# [482 rows x 180 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac = 0.5)
control
# Out:
#             Name Section  \
# 270      Juliana     Y01
# 614       Rohan      Y27
# 548  Christopher     Y25
# 568       Albert     Y03
# 585      Aditya      Y07
# ..           ...     ...
# 65       William     Y18
# 123         Jess     Y20
# 390        Jacob     Y10
# 214       Mahir      Y23
# 717         Yang     Y15
#
#     Does your NetID ending with odd number or even number?  \
# 270                     NetID ends with an even number
# 614                     NetID ends with an even number
# 548                     NetID ends with an even number
# 568                      NetID ends with an odd number
# 585                      NetID ends with an odd number
# ..                                                 ...
# 65                      NetID ends with an even number
# 123                      NetID ends with an odd number
# 390                      NetID ends with an odd number
# 214                     NetID ends with an even number
# 717                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 270                                              Heads
# 614                                              Tails
# 548                                              Heads
# 568                                              Heads
# 585                                              Tails
# ..                                                 ...
# 65                                               Heads
# 123                                              Heads
# 390                                              Tails
# 214                                              Tails
# 717                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 270                              Donuts                    1.0
# 614                               Tacos                    1.0
# 548                               Tacos                    0.0
# 568                              Donuts                    1.0
# 585                               Tacos                    1.0
# ..                                  ...                    ...
# 65                                Tacos                    0.0
# 123                              Donuts                    1.0
# 390                              Donuts                    0.0
# 214                              Donuts                    1.0
# 717                              Donuts                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 270                 Not a Freshman                         Night Person
# 614            Freshman in College                       Morning Person
# 548            Freshman in College                       Morning Person
# 568                 Not a Freshman                         Night Person
# 585                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 65                  Not a Freshman                         Night Person
# 123            Freshman in College                         Night Person
# 390            Freshman in College                       Morning Person
# 214            Freshman in College                         Night Person
# 717                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 270                          Afternoon Person
# 614                            Morning Person
# 548                          Afternoon Person
# 568                          Afternoon Person
# 585                          Afternoon Person
# ..                                        ...
# 65                             Morning Person
# 123                          Afternoon Person
# 390                            Morning Person
# 214                          Afternoon Person
# 717                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 270                                     Out-of-state  ...
# 614                                     Out-of-state  ...
# 548                                         Illinois  ...
# 568                                         Illinois  ...
# 585                                     Out-of-state  ...
# ..                                               ...  ...
# 65                                      Out-of-state  ...
# 123                                         Illinois  ...
# 390                                         Illinois  ...
# 214                                     Out-of-state  ...
# 717                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 270                                                Y01
# 614                                                Y27
# 548                                                Y25
# 568                                                Y03
# 585                                                Y07
# ..                                                 ...
# 65                                                 Y18
# 123                                                Y20
# 390                                                Y10
# 214                                                Y23
# 717                                                Y15
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 270                                               Mild
# 614                                             Strong
# 548                                               Mild
# 568                                             strong
# 585                                            Extreme
# ..                                                 ...
# 65                                            moderate
# 123                                               Mild
# 390                                               mild
# 214                                             Strong
# 717                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 270                                              Media
# 614                          Accounting + Data Science
# 548                                               Gies
# 568                      School of Information Science
# 585                                                Las
# ..                                                 ...
# 65                                                ACES
# 123                                               Gies
# 390                                           Business
# 214                                        CS and Math
# 717                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 270                                Computer Science
# 614                                Computer Science
# 548                                 Rocket Science
# 568                                             ECE
# 585                                             Ece
# ..                                              ...
# 65                                              ECE
# 123                               Computer science
# 390                           Computer engineering
# 214                                           Math
# 717                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 270                                  KPop                          Blackpink
# 614                                   Rap                             J Cole
# 548                                  Rock                       Trippie Redd
# 568                                   Rap                           Lil Baby
# 585                               Hip-hop                              Drake
# ..                                    ...                                ...
# 65                              Pop Music                           Coldplay
# 123                                   Pop                             Weeknd
# 390                                Indie                          Zach Bryan
# 214                                   Rap                         Kanye West
# 717                                  KPOP                              aespa
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 270                              Instagram                          INI
# 614                              Instagram                        I-N-I
# 548                                Youtube                        What?
# 568                              Instagram                          INI
# 585                                  Insta                          INI
# ..                                     ...                          ...
# 65                                  Wechat                   Go illini!
# 123                              Snapchat                      I don’t
# 390                                 Tiktok                          INI
# 214                             Instagram                           INI
# 717                              instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 270                                               PUBG
# 614                                         Basketball
# 548                                         Pickleball
# 568                                         Baskebtall
# 585                                               Fifa
# ..                                                 ...
# 65                                           FIFA 2024
# 123                                         Minecraft
# 390                                         Spike ball
# 214                                             Soccer
# 717                                          Minecraft
#
#     What is your dream vacation location?
# 270                               Iceland
# 614                                 Paris
# 548                                 Crete
# 568                                Japan
# 585                                Greece
# ..                                    ...
# 65                                 German
# 123                                  Bali
# 390                             Bora Bora
# 214                                    LA
# 717                           New Zealand
#
# [482 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#              Name Section  \
# 1      Prof. Wade  L1, L2
# 2          Andrew     Y05
# 3        Annabel      Y05
# 4          Ayden      Y14
# 6           Suvan     Y22
# ..            ...     ...
# 943  Emily Keller     Y21
# 954         Junyu  \t Y36
# 956       Fabian      Y11
# 957       Arseniy     Y20
# 961         Peter     Y09
#
#     Does your NetID ending with odd number or even number?  \
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 943                     NetID ends with an even number
# 954                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 957                                                NaN
# 961                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                                Heads
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# 6                                                Heads
# ..                                                 ...
# 943                                              Heads
# 954                                              Heads
# 956                                              Tails
# 957                                              Heads
# 961                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 943                               Tacos                    1.0
# 954                               Tacos                    1.0
# 956                               Tacos                    0.0
# 957                               Tacos                    1.0
# 961                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 943            Freshman in College                         Night Person
# 954            Freshman in College                         Night Person
# 956                 Not a Freshman                         Night Person
# 957                 Not a Freshman                         Night Person
# 961                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 1                            Afternoon Person
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 943                          Afternoon Person
# 954                          Afternoon Person
# 956                          Afternoon Person
# 957                          Afternoon Person
# 961                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 943                                         Illinois  ...
# 954                                     Out-of-state  ...
# 956                                         Illinois  ...
# 957                                     Out-of-state  ...
# 961                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 1                                               L1, L2
# 2                                                  Y05
# 3                                                  Y05
# 4                                                  Y14
# 6                                                  Y22
# ..                                                 ...
# 943                                                Y21
# 954                                             \t Y36
# 956                                                Y11
# 957                                                Y20
# 961                                                Y09
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                             Moderate
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# 6                                               Strong
# ..                                                 ...
# 943                                           moderate
# 954                                             strong
# 956                                           Extreme
# 957                                           moderate
# 961                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                             Grainger
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# 6                      Statistics and Computer Science
# ..                                                 ...
# 943                                           Grainger
# 954                               information science
# 956                                                 IS
# 957                                                NaN
# 961                                                 CS
#
#     What do you think is the hardest major at UIUC?  \
# 1                                           Physics
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# 6                              Computer Engineering
# ..                                              ...
# 943                                     Engineering
# 954                                              CS
# 956                               Computer science
# 957                                             NaN
# 961                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 943                                   Pop                       Taylor Swift
# 954                                Hiphop                Tyler, The Creator
# 956                                   Rap                              Drake
# 957                                   NaN                                NaN
# 961                                  Jazz                                 Ye
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 943                                Tik Tok                          INI
# 954                                    Ins                         good
# 956                                      X                        I-N-I
# 957                                    NaN                        I-N-I
# 961                                     QQ                         illi
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# 6                                         20 questions
# ..                                                 ...
# 943                                           Fortnite
# 954                                             Soccer
# 956                                          Valorant
# 957                                                NaN
# 961                                     Clash of clans
#
#     What is your dream vacation location?
# 1                               Mountains
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# 6                             Switzerland
# ..                                    ...
# 943                                 Italy
# 954                          Sanya, China
# 956                                Greece
# 957                        Moscow, Russia
# 961                               Iceland
#
# [247 rows x 180 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# ✏️(*Becuase frac is randomly select fraction of rows. It's really common that the people is include in both group in the 2 of the randomly select.✏️)*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index. isin(treatment. index) ]
control
# Out:
#                        Name Section  \
# 5                      Sens     Y30
# 7                Joseph Kim     Y16
# 8                     Sarah     Y36
# 9           Pradnyan Khodke     Y24
# 12                     Ryan     Y30
# ..                      ...     ...
# 953                   Laura     Y28
# 955                lijiajin     Y01
# 958                  Hanle      Y12
# 960  Mohammed Fatheen Ahmed     Y22
# 962                   Nyssa     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 5                       NetID ends with an even number
# 7                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# 12                      NetID ends with an even number
# ..                                                 ...
# 953                     NetID ends with an even number
# 955                      NetID ends with an odd number
# 958                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 962                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 5                                                Heads
# 7                                                Heads
# 8                                                Heads
# 9                                                Heads
# 12                                               Heads
# ..                                                 ...
# 953                                              Heads
# 955                                              Heads
# 958                                              Heads
# 960                                              Heads
# 962                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 5                                 Tacos                    1.0
# 7                                Donuts                    1.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# 12                               Donuts                    0.0
# ..                                  ...                    ...
# 953                              Donuts                    0.0
# 955                              Donuts                    0.0
# 958                              Donuts                    0.0
# 960                              Donuts                    0.0
# 962                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 5              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# 12             Freshman in College                         Night Person
# ..                             ...                                  ...
# 953            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 958                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 962            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 5                              Morning Person
# 7                            Afternoon Person
# 8                              Morning Person
# 9                              Morning Person
# 12                           Afternoon Person
# ..                                        ...
# 953                          Afternoon Person
# 955                            Morning Person
# 958                          Afternoon Person
# 960                            Morning Person
# 962                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 5                                           Illinois  ...
# 7                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# 12                                          Illinois  ...
# ..                                               ...  ...
# 953                                     Out-of-state  ...
# 955                                     Out-of-state  ...
# 958                                     Out-of-state  ...
# 960                                         Illinois  ...
# 962                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 5                                                  Y30
# 7                                                  Y16
# 8                                                  Y36
# 9                                                  Y24
# 12                                                 Y30
# ..                                                 ...
# 953                                                Y28
# 955                                                Y01
# 958                                                Y12
# 960                                                Y22
# 962                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 5                                             Moderate
# 7                                                 Mild
# 8                                               Strong
# 9                                               Strong
# 12                                            Moderate
# ..                                                 ...
# 953                                             Strong
# 955                                             strong
# 958                                             strong
# 960                                             strong
# 962                                               mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 5                                     Grainger and LAS
# 7                                                  LAS
# 8                                              iSchool
# 9                                                  LAS
# 12                                                 LAS
# ..                                                 ...
# 953                                               Gies
# 955                                                 cs
# 958                                               Gies
# 960                                                las
# 962                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 5                                               ECE
# 7                                  Computer Science
# 8                                  Computer Science
# 9                                               ECE
# 12                                          Physics
# ..                                              ...
# 953                                    Engineering
# 955                                              cs
# 958                                             ECE
# 960                                              CS
# 962                                             ece
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 5                                Shoegaze                        Fiona Apple
# 7                              soundtrack             Ski Mask the Slump God
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# 12                                   Rock               Two Door Cinema Club
# ..                                    ...                                ...
# 953                                   Pop                         Eason Chen
# 955                                   sad                           Lana Ray
# 958                                   All                        Post Malone
# 960                                   rap                              Drake
# 962                                   pop                       taylor swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 5                                  Twitter                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# 12                                 youtube                  **silence**
# ..                                     ...                          ...
# 953                              Instagram                        I-N-I
# 955                                    ins                        I-N-N
# 958                                twitter                          ill
# 960                                   Snap                         ini
# 962                                twitter                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 5                                            Fall Guys
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 8                                                  Uno
# 9                                           Basketball
# 12                                          Overcooked
# ..                                                 ...
# 953                                               2048
# 955                                           valorant
# 958                                  Rainbow six siege
# 960                                       apex legends
# 962                                         code names
#
#     What is your dream vacation location?
# 5                                      PR
# 7                                 Nowhere
# 8                                  Taiwan
# 9                                    Asia
# 12              Grand Teton National Park
# ..                                    ...
# 953                                europe
# 955                               finland
# 958                       Japan, Hokkaido
# 960                                europe
# 962                                greece
#
# [483 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
# ...feel free to add extra "Code" cells here if needed.

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# *(✏️ Edit this cell to replace this text wth your answer. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac = 0.5)
df1_treatment
# Out:
#                       Name Section  \
# 531                 Landie     Y35
# 736                   Will     Y02
# 756                   Maks     Y04
# 12                    Ryan     Y30
# 232                 Audrey     Y28
# ..                     ...     ...
# 858  CA Victoria Cichowski     Y24
# 666               Brennan      Y18
# 636                  Aditi     Y19
# 655                  Jerry     Y10
# 925                Juliana     Y12
#
#     Does your NetID ending with odd number or even number?  \
# 531                      NetID ends with an odd number
# 736                      NetID ends with an odd number
# 756                      NetID ends with an odd number
# 12                      NetID ends with an even number
# 232                     NetID ends with an even number
# ..                                                 ...
# 858                     NetID ends with an even number
# 666                     NetID ends with an even number
# 636                     NetID ends with an even number
# 655                      NetID ends with an odd number
# 925                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 531                                              Heads
# 736                                              Tails
# 756                                              Heads
# 12                                               Heads
# 232                                              Heads
# ..                                                 ...
# 858                                              Heads
# 666                                              Tails
# 636                                              Tails
# 655                                              Heads
# 925                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 531                               Tacos                    1.0
# 736                              Donuts                    1.0
# 756                               Tacos                    NaN
# 12                               Donuts                    0.0
# 232                              Donuts                    0.0
# ..                                  ...                    ...
# 858                              Donuts                    1.0
# 666                              Donuts                    1.0
# 636                               Tacos                    1.0
# 655                              Donuts                    0.0
# 925                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 531            Freshman in College                         Night Person
# 736                 Not a Freshman                         Night Person
# 756                 Not a Freshman                         Night Person
# 12             Freshman in College                         Night Person
# 232                 Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 858                 Not a Freshman                         Night Person
# 666            Freshman in College                         Night Person
# 636                 Not a Freshman                         Night Person
# 655            Freshman in College                         Night Person
# 925            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 531                          Afternoon Person
# 736                          Afternoon Person
# 756                          Afternoon Person
# 12                           Afternoon Person
# 232                            Morning Person
# ..                                        ...
# 858                          Afternoon Person
# 666                          Afternoon Person
# 636                          Afternoon Person
# 655                          Afternoon Person
# 925                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 531                                     Out-of-state  ...
# 736                                         Illinois  ...
# 756                                         Illinois  ...
# 12                                          Illinois  ...
# 232                                         Illinois  ...
# ..                                               ...  ...
# 858                                         Illinois  ...
# 666                                         Illinois  ...
# 636                                              NaN  ...
# 655                                     Out-of-state  ...
# 925                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 531                                                Y35
# 736                                                Y02
# 756                                                Y04
# 12                                                 Y30
# 232                                                Y28
# ..                                                 ...
# 858                                                Y24
# 666                                                Y18
# 636                                                Y19
# 655                                                Y10
# 925                                                Y12
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 531                                             strong
# 736                                           Moderate
# 756                                           Moderate
# 12                                            Moderate
# 232                                           Moderate
# ..                                                 ...
# 858                                               none
# 666                                               Mild
# 636                                                NaN
# 655                                               mild
# 925                                               none
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 531                                                LAS
# 736                                               Gies
# 756                                                LAS
# 12                                                 LAS
# 232                                                LAS
# ..                                                 ...
# 858                                               Gies
# 666                                               Gies
# 636                                                NaN
# 655                                               Math
# 925                                      Gies Business
#
#     What do you think is the hardest major at UIUC?  \
# 531                                              CS
# 736                                         Finance
# 756                                              CS
# 12                                          Physics
# 232                               Computer Science
# ..                                              ...
# 858                                              cs
# 666                                              CS
# 636                                             NaN
# 655                                        Computer
# 925                                       Chemistry
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 531                       Kpop and hiphop                          Seventeen
# 736                               Country                              Drake
# 756                                   Rap                       Travis Scott
# 12                                   Rock               Two Door Cinema Club
# 232                            Indie Rock                       Taylor Swift
# ..                                    ...                                ...
# 858                                  kpop                            enhypen
# 666                                   Rap                           King Von
# 636                                   NaN                                NaN
# 655                         country music                             Mozart
# 925                             Reggaeton                            Shakira
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 531                   Wechat and instagram                    I-N-O-I-S
# 736                                Twitter                          INI
# 756                                Tik Tok                        I-N-I
# 12                                 youtube                  **silence**
# 232                              Pinterest                        I-N-I
# ..                                     ...                          ...
# 858                                 tiktok                        I-N-I
# 666                              Instagram                          INI
# 636                                    NaN                          NaN
# 655                                 Wechat                        I-N-I
# 925                              Instagram                        I-N-N
#
#     What is your favorite game to play (either video game or IRL)?  \
# 531                                                NaN
# 736                                           Baseball
# 756                                                 2k
# 12                                          Overcooked
# 232                                          Minecraft
# ..                                                 ...
# 858                                             hayday
# 666                                                Uno
# 636                                                NaN
# 655                                  Prior of the King
# 925                                       Call of Duty
#
#     What is your dream vacation location?
# 531                           Switzerland
# 736                                 Italy
# 756                                Hawaii
# 12              Grand Teton National Park
# 232                           Coppenhagen
# ..                                    ...
# 858                                 seoul
# 666                                Brazil
# 636                                   NaN
# 655                               Finland
# 925                             Bora Bora
#
# [202 rows x 180 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index. isin(df1_treatment. index) ]
df1_control
# Out:
#                        Name Section  \
# 3                  Annabel      Y05
# 7                Joseph Kim     Y16
# 10                  Aaliyah     Y13
# 18                  Jackson     Y21
# 21                   Jayden     Y36
# ..                      ...     ...
# 940                  Magali     Y21
# 942                   Billy     Y29
# 949                Vihaansh     Y08
# 960  Mohammed Fatheen Ahmed     Y22
# 963                  maddax      Y2
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 7                       NetID ends with an even number
# 10                      NetID ends with an even number
# 18                      NetID ends with an even number
# 21                       NetID ends with an odd number
# ..                                                 ...
# 940                      NetID ends with an odd number
# 942                     NetID ends with an even number
# 949                      NetID ends with an odd number
# 960                      NetID ends with an odd number
# 963                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 7                                                Heads
# 10                                               Heads
# 18                                               Tails
# 21                                               Heads
# ..                                                 ...
# 940                                              Heads
# 942                                              Heads
# 949                                              Heads
# 960                                              Heads
# 963                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 7                                Donuts                    1.0
# 10                               Donuts                    1.0
# 18                                Tacos                    1.0
# 21                               Donuts                    1.0
# ..                                  ...                    ...
# 940                               Tacos                    0.0
# 942                               Tacos                    1.0
# 949                               Tacos                    1.0
# 960                              Donuts                    0.0
# 963                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 7                   Not a Freshman                         Night Person
# 10             Freshman in College                         Night Person
# 18             Freshman in College                         Night Person
# 21                  Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 940            Freshman in College                         Night Person
# 942            Freshman in College                         Night Person
# 949                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 963            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 7                            Afternoon Person
# 10                           Afternoon Person
# 18                           Afternoon Person
# 21                             Morning Person
# ..                                        ...
# 940                          Afternoon Person
# 942                          Afternoon Person
# 949                          Afternoon Person
# 960                            Morning Person
# 963                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 7                                           Illinois  ...
# 10                                          Illinois  ...
# 18                                          Illinois  ...
# 21                                      Out-of-state  ...
# ..                                               ...  ...
# 940                                         Illinois  ...
# 942                                         Illinois  ...
# 949                                     Out-of-state  ...
# 960                                         Illinois  ...
# 963                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 3                                                  Y05
# 7                                                  Y16
# 10                                                 Y13
# 18                                                 Y21
# 21                                                 Y36
# ..                                                 ...
# 940                                                Y21
# 942                                                Y29
# 949                                                Y08
# 960                                                Y22
# 963                                                 Y2
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 7                                                 Mild
# 10                                             Extreme
# 18                                            Moderate
# 21                                              strong
# ..                                                 ...
# 940                                             strong
# 942                                             strong
# 949                                            Extreme
# 960                                             strong
# 963                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 7                                                  LAS
# 10                                             iSchool
# 18                                                Gies
# 21                                                 LAS
# ..                                                 ...
# 940                                                NaN
# 942                                                LAS
# 949                               Computer Engineering
# 960                                                las
# 963                          finance with data science
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 7                                  Computer Science
# 10                                 Computer Science
# 18                                      Engineering
# 21                                               CS
# ..                                              ...
# 940                                              cs
# 942                               Computer science
# 949                          Electrical Engineering
# 960                                              CS
# 963                                         general
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 7                              soundtrack             Ski Mask the Slump God
# 10                                    Pop                       Taylor Swift
# 18                                Country                      Morgan Wallen
# 21                              pop music                       Taylor Swift
# ..                                    ...                                ...
# 940                                 indie                       harry styles
# 942                                   Rap                             Polo g
# 949                                  Rock                             Eminem
# 960                                   rap                              Drake
# 963                                   rap                       lil uzi vert
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 7                                Instagram                    I-N-O-I-S
# 10                                  TikTok                          INI
# 18                                Snapchat                          INI
# 21                                  WeChat                          NIN
# ..                                     ...                          ...
# 940                                tik tok                          ini
# 942                                 Tiktok                          INI
# 949                              Instagram                        I-N-I
# 960                                   Snap                         ini
# 963                               snapchat                          ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 10                                    Capture the Flag
# 18                                              Soccer
# 21                                               NBA2K
# ..                                                 ...
# 940                                       call of duty
# 942                                           Lacrosse
# 949                                             Soccer
# 960                                       apex legends
# 963                                        quiet game
#
#     What is your dream vacation location?
# 3                                 Greece
# 7                                 Nowhere
# 10                                  Spain
# 18                                 Hawaii
# 21                                 Hawaii
# ..                                    ...
# 940                                Mexico
# 942                                  Ohio
# 949                                Norway
# 960                                europe
# 963                    middle of nowhere
#
# [203 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac = 0.5)
df2_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 426    Arnav     Y14                      NetID ends with an odd number
# 239     Abby     Y12                     NetID ends with an even number
# 953    Laura     Y28                     NetID ends with an even number
# 558     Aman     Y27                     NetID ends with an even number
# 810    Jakob     Y22                     NetID ends with an even number
# ..       ...     ...                                                ...
# 907  Tarina     Y20                       NetID ends with an odd number
# 70   Christy     Y18                     NetID ends with an even number
# 77    Kshama     Y16                     NetID ends with an even number
# 147  Matthew     Y28                      NetID ends with an odd number
# 604     Anya     Y22                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 426                                              Heads
# 239                                              Heads
# 953                                              Heads
# 558                                              Heads
# 810                                              Tails
# ..                                                 ...
# 907                                              Heads
# 70                                               Heads
# 77                                               Heads
# 147                                              Heads
# 604                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 426                               Tacos                    1.0
# 239                              Donuts                    1.0
# 953                              Donuts                    0.0
# 558                              Donuts                    0.0
# 810                               Tacos                    0.0
# ..                                  ...                    ...
# 907                               Tacos                    1.0
# 70                                Tacos                    1.0
# 77                                Tacos                    1.0
# 147                              Donuts                    0.0
# 604                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 426                 Not a Freshman                         Night Person
# 239            Freshman in College                       Morning Person
# 953            Freshman in College                         Night Person
# 558            Freshman in College                         Night Person
# 810            Freshman in College                         Night Person
# ..                             ...                                  ...
# 907            Freshman in College                         Night Person
# 70                  Not a Freshman                       Morning Person
# 77                  Not a Freshman                       Morning Person
# 147            Freshman in College                         Night Person
# 604            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 426                          Afternoon Person
# 239                            Morning Person
# 953                          Afternoon Person
# 558                          Afternoon Person
# 810                          Afternoon Person
# ..                                        ...
# 907                          Afternoon Person
# 70                             Morning Person
# 77                             Morning Person
# 147                          Afternoon Person
# 604                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 426                                     Out-of-state  ...
# 239                                     Out-of-state  ...
# 953                                     Out-of-state  ...
# 558                                         Illinois  ...
# 810                                         Illinois  ...
# ..                                               ...  ...
# 907                                         Illinois  ...
# 70                                          Illinois  ...
# 77                                          Illinois  ...
# 147                                         Illinois  ...
# 604                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 426                                                Y14
# 239                                                Y12
# 953                                                Y28
# 558                                                Y27
# 810                                                Y22
# ..                                                 ...
# 907                                               Y20
# 70                                                 Y18
# 77                                                 Y16
# 147                                                Y28
# 604                                                Y22
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 426                                             Strong
# 239                                           moderate
# 953                                             Strong
# 558                                             strong
# 810                                           moderate
# ..                                                 ...
# 907                                             strong
# 70                                            Moderate
# 77                                            moderate
# 147                                               Mild
# 604                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 426                             Finance + Data Science
# 239                                               Gies
# 953                                               Gies
# 558                                           CS+stats
# 810                                               Gies
# ..                                                 ...
# 907                                  Actuarial science
# 70                                             iSchool
# 77                                                 LAS
# 147                                                LAS
# 604                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 426                                Computer science
# 239                                     engineering
# 953                                    Engineering
# 558                         electrical engineering
# 810                                Computer Science
# ..                                              ...
# 907                                computer science
# 70                                Engineering PHDs
# 77                                              ECE
# 147                                     Engineering
# 604                                             NaN
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 426                                   Pop                         The Weeknd
# 239                                   NaN                                NaN
# 953                                   Pop                         Eason Chen
# 558                                   pop                               Joji
# 810                                   RnB                       Lana Del Rey
# ..                                    ...                                ...
# 907                               r and b                       Taylor swift
# 70                                  Happy                           NewJeans
# 77                                    RNB                  Sabrina Carpenter
# 147                                   NaN                                NaN
# 604                                   Pop                                NaN
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 426                              Instagram                        I-N-I
# 239                               Snapchat                        I-N-I
# 953                              Instagram                        I-N-I
# 558                              Instagram                          ini
# 810                                 TikTok                        I-N-I
# ..                                     ...                          ...
# 907                                 TikTok                          Ill
# 70                               Instagram                         SICK
# 77                                  tiktok                          INI
# 147                                Twitter                          INI
# 604                              Instagram                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 426                                               Fifa
# 239                                                NaN
# 953                                               2048
# 558                                     subway surfers
# 810                                          minecraft
# ..                                                 ...
# 907                                                NaN
# 70                                            Plate Up
# 77                                                 irl
# 147                                           Baseball
# 604                                                NaN
#
#     What is your dream vacation location?
# 426                                Monaco
# 239                                Europe
# 953                                europe
# 558                          Banff Canada
# 810                                Greece
# ..                                    ...
# 907                                France
# 70                                  Japan
# 77                         toronto canada
# 147                                  Rome
# 604                                   NaN
#
# [274 rows x 180 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[ ~df2.index. isin(df2_treatment. index) ]
df2_control
# Out:
#            Name Section  \
# 1    Prof. Wade  L1, L2
# 2        Andrew     Y05
# 8         Sarah     Y36
# 11        Finch     Y03
# 13       rachel     Y18
# ..          ...     ...
# 954       Junyu  \t Y36
# 956     Fabian      Y11
# 961       Peter     Y09
# 962       Nyssa     Y23
# 964  CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 8                        NetID ends with an odd number
# 11                      NetID ends with an even number
# 13                      NetID ends with an even number
# ..                                                 ...
# 954                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 1                                                Heads
# 2                                                Heads
# 8                                                Heads
# 11                                               Tails
# 13                                               Tails
# ..                                                 ...
# 954                                              Heads
# 956                                              Tails
# 961                                              Heads
# 962                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 8                                Donuts                    0.0
# 11                               Donuts                    0.0
# 13                                Tacos                    1.0
# ..                                  ...                    ...
# 954                               Tacos                    1.0
# 956                               Tacos                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# 11                  Not a Freshman                       Morning Person
# 13             Freshman in College                         Night Person
# ..                             ...                                  ...
# 954            Freshman in College                         Night Person
# 956                 Not a Freshman                         Night Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 1                            Afternoon Person
# 2                            Afternoon Person
# 8                              Morning Person
# 11                             Morning Person
# 13                             Morning Person
# ..                                        ...
# 954                          Afternoon Person
# 956                          Afternoon Person
# 961                            Morning Person
# 962                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 8                                           Illinois  ...
# 11                                          Illinois  ...
# 13                                          Illinois  ...
# ..                                               ...  ...
# 954                                     Out-of-state  ...
# 956                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 1                                               L1, L2
# 2                                                  Y05
# 8                                                  Y36
# 11                                                 Y03
# 13                                                 Y18
# ..                                                 ...
# 954                                             \t Y36
# 956                                                Y11
# 961                                                Y09
# 962                                                Y23
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 1                                             Moderate
# 2                                             moderate
# 8                                               Strong
# 11                                                 NaN
# 13                                              strong
# ..                                                 ...
# 954                                             strong
# 956                                           Extreme
# 961                                             strong
# 962                                               mild
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 1                                             Grainger
# 2                                                  LAS
# 8                                              iSchool
# 11                                    College of Media
# 13                                           grainger
# ..                                                 ...
# 954                               information science
# 956                                                 IS
# 961                                                 CS
# 962                                                las
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 1                                           Physics
# 2                                                CS
# 8                                  Computer Science
# 11                                              NaN
# 13                         biochemical engineering
# ..                                              ...
# 954                                              CS
# 956                               Computer science
# 961                                              CS
# 962                                             ece
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 8                                   Indie                       Taylor Swift
# 11                                    Yes                       Saint Asonia
# 13                                    pop                           newjeans
# ..                                    ...                                ...
# 954                                Hiphop                Tyler, The Creator
# 956                                   Rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 8                                Instagram                        I-N-I
# 11                                  TikTok                        I-N-I
# 13                              instagram                         I-N-I
# ..                                     ...                          ...
# 954                                    Ins                         good
# 956                                      X                        I-N-I
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 2                                               soccer
# 8                                                  Uno
# 11                                               Palia
# 13                                              euchre
# ..                                                 ...
# 954                                             Soccer
# 956                                          Valorant
# 961                                     Clash of clans
# 962                                         code names
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 1                               Mountains
# 2                                  Hawaii
# 8                                  Taiwan
# 11                                    NaN
# 13                                 hawaii
# ..                                    ...
# 954                          Sanya, China
# 956                                Greece
# 961                               Iceland
# 962                                greece
# 964                                 Korea
#
# [274 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd. concat( [df1_treatment, df2_treatment])
treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 531   Landie     Y35                      NetID ends with an odd number
# 736     Will     Y02                      NetID ends with an odd number
# 756     Maks     Y04                      NetID ends with an odd number
# 12      Ryan     Y30                     NetID ends with an even number
# 232   Audrey     Y28                     NetID ends with an even number
# ..       ...     ...                                                ...
# 907  Tarina     Y20                       NetID ends with an odd number
# 70   Christy     Y18                     NetID ends with an even number
# 77    Kshama     Y16                     NetID ends with an even number
# 147  Matthew     Y28                      NetID ends with an odd number
# 604     Anya     Y22                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 531                                              Heads
# 736                                              Tails
# 756                                              Heads
# 12                                               Heads
# 232                                              Heads
# ..                                                 ...
# 907                                              Heads
# 70                                               Heads
# 77                                               Heads
# 147                                              Heads
# 604                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 531                               Tacos                    1.0
# 736                              Donuts                    1.0
# 756                               Tacos                    NaN
# 12                               Donuts                    0.0
# 232                              Donuts                    0.0
# ..                                  ...                    ...
# 907                               Tacos                    1.0
# 70                                Tacos                    1.0
# 77                                Tacos                    1.0
# 147                              Donuts                    0.0
# 604                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 531            Freshman in College                         Night Person
# 736                 Not a Freshman                         Night Person
# 756                 Not a Freshman                         Night Person
# 12             Freshman in College                         Night Person
# 232                 Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 907            Freshman in College                         Night Person
# 70                  Not a Freshman                       Morning Person
# 77                  Not a Freshman                       Morning Person
# 147            Freshman in College                         Night Person
# 604            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 531                          Afternoon Person
# 736                          Afternoon Person
# 756                          Afternoon Person
# 12                           Afternoon Person
# 232                            Morning Person
# ..                                        ...
# 907                          Afternoon Person
# 70                             Morning Person
# 77                             Morning Person
# 147                          Afternoon Person
# 604                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 531                                     Out-of-state  ...
# 736                                         Illinois  ...
# 756                                         Illinois  ...
# 12                                          Illinois  ...
# 232                                         Illinois  ...
# ..                                               ...  ...
# 907                                         Illinois  ...
# 70                                          Illinois  ...
# 77                                          Illinois  ...
# 147                                         Illinois  ...
# 604                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 531                                                Y35
# 736                                                Y02
# 756                                                Y04
# 12                                                 Y30
# 232                                                Y28
# ..                                                 ...
# 907                                               Y20
# 70                                                 Y18
# 77                                                 Y16
# 147                                                Y28
# 604                                                Y22
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 531                                             strong
# 736                                           Moderate
# 756                                           Moderate
# 12                                            Moderate
# 232                                           Moderate
# ..                                                 ...
# 907                                             strong
# 70                                            Moderate
# 77                                            moderate
# 147                                               Mild
# 604                                             Strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 531                                                LAS
# 736                                               Gies
# 756                                                LAS
# 12                                                 LAS
# 232                                                LAS
# ..                                                 ...
# 907                                  Actuarial science
# 70                                             iSchool
# 77                                                 LAS
# 147                                                LAS
# 604                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 531                                              CS
# 736                                         Finance
# 756                                              CS
# 12                                          Physics
# 232                               Computer Science
# ..                                              ...
# 907                                computer science
# 70                                Engineering PHDs
# 77                                              ECE
# 147                                     Engineering
# 604                                             NaN
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 531                       Kpop and hiphop                          Seventeen
# 736                               Country                              Drake
# 756                                   Rap                       Travis Scott
# 12                                   Rock               Two Door Cinema Club
# 232                            Indie Rock                       Taylor Swift
# ..                                    ...                                ...
# 907                               r and b                       Taylor swift
# 70                                  Happy                           NewJeans
# 77                                    RNB                  Sabrina Carpenter
# 147                                   NaN                                NaN
# 604                                   Pop                                NaN
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 531                   Wechat and instagram                    I-N-O-I-S
# 736                                Twitter                          INI
# 756                                Tik Tok                        I-N-I
# 12                                 youtube                  **silence**
# 232                              Pinterest                        I-N-I
# ..                                     ...                          ...
# 907                                 TikTok                          Ill
# 70                               Instagram                         SICK
# 77                                  tiktok                          INI
# 147                                Twitter                          INI
# 604                              Instagram                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 531                                                NaN
# 736                                           Baseball
# 756                                                 2k
# 12                                          Overcooked
# 232                                          Minecraft
# ..                                                 ...
# 907                                                NaN
# 70                                            Plate Up
# 77                                                 irl
# 147                                           Baseball
# 604                                                NaN
#
#     What is your dream vacation location?
# 531                           Switzerland
# 736                                 Italy
# 756                                Hawaii
# 12              Grand Teton National Park
# 232                           Coppenhagen
# ..                                    ...
# 907                                France
# 70                                  Japan
# 77                         toronto canada
# 147                                  Rome
# 604                                   NaN
#
# [476 rows x 180 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd. concat( [df1_control, df2_control])
control
# Out:
#            Name Section  \
# 3      Annabel      Y05
# 7    Joseph Kim     Y16
# 10      Aaliyah     Y13
# 18      Jackson     Y21
# 21       Jayden     Y36
# ..          ...     ...
# 954       Junyu  \t Y36
# 956     Fabian      Y11
# 961       Peter     Y09
# 962       Nyssa     Y23
# 964  CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 7                       NetID ends with an even number
# 10                      NetID ends with an even number
# 18                      NetID ends with an even number
# 21                       NetID ends with an odd number
# ..                                                 ...
# 954                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 7                                                Heads
# 10                                               Heads
# 18                                               Tails
# 21                                               Heads
# ..                                                 ...
# 954                                              Heads
# 956                                              Tails
# 961                                              Heads
# 962                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 7                                Donuts                    1.0
# 10                               Donuts                    1.0
# 18                                Tacos                    1.0
# 21                               Donuts                    1.0
# ..                                  ...                    ...
# 954                               Tacos                    1.0
# 956                               Tacos                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 7                   Not a Freshman                         Night Person
# 10             Freshman in College                         Night Person
# 18             Freshman in College                         Night Person
# 21                  Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 954            Freshman in College                         Night Person
# 956                 Not a Freshman                         Night Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 7                            Afternoon Person
# 10                           Afternoon Person
# 18                           Afternoon Person
# 21                             Morning Person
# ..                                        ...
# 954                          Afternoon Person
# 956                          Afternoon Person
# 961                            Morning Person
# 962                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 7                                           Illinois  ...
# 10                                          Illinois  ...
# 18                                          Illinois  ...
# 21                                      Out-of-state  ...
# ..                                               ...  ...
# 954                                     Out-of-state  ...
# 956                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 3                                                  Y05
# 7                                                  Y16
# 10                                                 Y13
# 18                                                 Y21
# 21                                                 Y36
# ..                                                 ...
# 954                                             \t Y36
# 956                                                Y11
# 961                                                Y09
# 962                                                Y23
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 7                                                 Mild
# 10                                             Extreme
# 18                                            Moderate
# 21                                              strong
# ..                                                 ...
# 954                                             strong
# 956                                           Extreme
# 961                                             strong
# 962                                               mild
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 7                                                  LAS
# 10                                             iSchool
# 18                                                Gies
# 21                                                 LAS
# ..                                                 ...
# 954                               information science
# 956                                                 IS
# 961                                                 CS
# 962                                                las
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 7                                  Computer Science
# 10                                 Computer Science
# 18                                      Engineering
# 21                                               CS
# ..                                              ...
# 954                                              CS
# 956                               Computer science
# 961                                              CS
# 962                                             ece
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 7                              soundtrack             Ski Mask the Slump God
# 10                                    Pop                       Taylor Swift
# 18                                Country                      Morgan Wallen
# 21                              pop music                       Taylor Swift
# ..                                    ...                                ...
# 954                                Hiphop                Tyler, The Creator
# 956                                   Rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 7                                Instagram                    I-N-O-I-S
# 10                                  TikTok                          INI
# 18                                Snapchat                          INI
# 21                                  WeChat                          NIN
# ..                                     ...                          ...
# 954                                    Ins                         good
# 956                                      X                        I-N-I
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 10                                    Capture the Flag
# 18                                              Soccer
# 21                                               NBA2K
# ..                                                 ...
# 954                                             Soccer
# 956                                          Valorant
# 961                                     Clash of clans
# 962                                         code names
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 3                                 Greece
# 7                                 Nowhere
# 10                                  Spain
# 18                                 Hawaii
# 21                                 Hawaii
# ..                                    ...
# 954                          Sanya, China
# 956                                Greece
# 961                               Iceland
# 962                                greece
# 964                                 Korea
#
# [477 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# *(✏️ Blocking is a technique to control for the effect of nuisance variables. This nuisance variables that affect the relationship between an explanatory variable. By doing Blocking, the variation within each block would be much lower compared to the variation among all individuals, and we would be able to gain a precise theory of how the explanatory variable affects the response variable.
#
# For example, now researchers want to understand that whether the new drugs is effect to the weitht loss. In this case, they could split individuals into two blocks based on gender and randomly assign individuals to one of two treatments: a new diet or a normal diet. By placing individuals into blocks, the relationship between the new diet and weight loss becomes more clear since we were able to control for the gender.✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
