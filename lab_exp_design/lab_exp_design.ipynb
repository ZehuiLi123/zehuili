# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Chengyang"
ca1_name = "Talia"
ca2_name = "Kirthi"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Jacky Zhang"
partner1_netid = "jackyz2"
partner1_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(✏️Edit this cell to add your group's question.✏️)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa23.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`. Don't forget to import pandas as well!

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa23.csv")
df
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 1                Prof. Wade  L1, L2
# 2                    Andrew     Y05
# 3                  Annabel      Y05
# 4                    Ayden      Y14
# ..                      ...     ...
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
# 962                   Nyssa     Y23
# 963                  maddax      Y2
# 964              CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 4                       NetID ends with an even number
# ..                                                 ...
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 3                                                Heads
# 4                                                Heads
# ..                                                 ...
# 960                                              Heads
# 961                                              Heads
# 962                                              Heads
# 963                                              Tails
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 4                                Donuts                    1.0
# ..                                  ...                    ...
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# ..                             ...                                  ...
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 3                            Afternoon Person
# 4                              Morning Person
# ..                                        ...
# 960                            Morning Person
# 961                            Morning Person
# 962                          Afternoon Person
# 963                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 4                                           Illinois  ...
# ..                                               ...  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 2                                                  Y05
# 3                                                  Y05
# 4                                                  Y14
# ..                                                 ...
# 960                                                Y22
# 961                                                Y09
# 962                                                Y23
# 963                                                 Y2
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 3                                             Moderate
# 4                                               Strong
# ..                                                 ...
# 960                                             strong
# 961                                             strong
# 962                                               mild
# 963                                            extreme
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 3                                     ISchool and LAS
# 4                                                 Gies
# ..                                                 ...
# 960                                                las
# 961                                                 CS
# 962                                                las
# 963                          finance with data science
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 3                                 Computer science
# 4                                   Any engineering
# ..                                              ...
# 960                                              CS
# 961                                              CS
# 962                                             ece
# 963                                         general
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 4                               Indie pop                      The Lumineers
# ..                                    ...                                ...
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 4                                 Snapchat                          INI
# ..                                     ...                          ...
# 960                                   Snap                         ini
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 963                               snapchat                          ini
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 3                             Volleyball or fortnight
# 4                                           Basketball
# ..                                                 ...
# 960                                       apex legends
# 961                                     Clash of clans
# 962                                         code names
# 963                                        quiet game
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 3                                 Greece
# 4                              Australia
# ..                                    ...
# 960                                europe
# 961                               Iceland
# 962                                greece
# 963                    middle of nowhere
# 964                                 Korea
#
# [965 rows x 180 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Does your NetID ending with odd number or even number?',
#  'If I flipped a coin, do you think it would it land on heads or tails?',
#  'Do you like to eat tacos or donuts?',
#  'Pick a Number: 0 or 1',
#  'Are you a freshman in college?',
#  'Are you a morning or a night person?',
#  'Are you a morning or an afternoon person?',
#  'Are you a student from Illinois or out-of-state?',
#  'Are you a student in Grainger?',
#  'Are you a Taylor Swift fan?',
#  'Are you a winter or summer person?',
#  'Are you above or equal to 5 foot 6 inches?',
#  'Are you an early bird or night owl?',
#  'Are you an extrovert or an introvert?',
#  'Are you an international student or from the United States?',
#  'Are you an underclassmen or lowerclassmen?',
#  'Is the day of the month of your birth even or odd?  (Ex: May 28 is even, but June 3 is odd)',
#  'Are you from the Chicago suburbs?',
#  'Are you in LAS?',
#  'Are you in the 9:00 AM or 11:00 AM DISCOVERY lecture?',
#  'Are you involved/will be involved in Greek life?',
#  'Are you living on or off campus?',
#  'Do you identify as a male or female?',
#  'Are you older than 18?',
#  'Are you sitting in a light or dark colored chair?',
#  'Are you the first person from your entire family to attend University of Illinois?',
#  'Are you wearing glasses right now?',
#  'Are your parents immigrants?',
#  'Beef or Chicken?',
#  'Chocolate or Vanilla?',
#  'Coffee or Tea?',
#  'Coke or Pepsi? ',
#  'Did you attend lecture on Friday?',
#  'Did you grow up in the Midwest?',
#  'Did you move in from the 13-16th or the 17-20th?',
#  'Did you sit on the left or the right side of the hall during the last lecture?',
#  'Do you consider a cup to be half empty or half full?',
#  'Do you dance?',
#  'Do you drink black coffee?',
#  'Do you drink coffee every day?',
#  'Do you eat breakfast in the morning?',
#  'Do you grow up in Illinois?',
#  'Do you hang your toilet paper over or under?',
#  'Do you have an iPhone?',
#  'Do you have an odd or even amount of letters in your first name?',
#  'Do you have any siblings?',
#  'Do you have black hair or non-black hair?',
#  'Do you have brown eyes or any other color?',
#  'Do you have short hair or long hair?',
#  'Do you have your Data Science Discovery lab section on Wednesday or after Wednesday?',
#  'Do you have your ears pierced?',
#  'Do you introduce yourself to a new person using "hi" or "hello"?',
#  'Do you like C++ or Java?',
#  'Do you like Chinese food?',
#  'Do you like dogs or cats?',
#  'Do you like football or basketball better?',
#  'Do you like ice cream?',
#  'Do you like orange juice or apple juice?',
#  'Do you like pancakes or waffles?',
#  'Pink or Blue?',
#  'Pizza or a burger?',
#  'Pizza or pasta?',
#  'Summer or Winter?',
#  'Do you like to wear hats?',
#  'Do you like UIUC?',
#  'Do you listen to music on the way to classes?',
#  'Do you live in a residence hall or private housing?',
#  'Do you prefer Nike or Adidas for shoes?',
#  'Do you prefer vanilla or chocolate ice cream? ',
#  'Burger or Taco?',
#  'Do you prefer American Football or Cricket?',
#  'Do you prefer apples or bananas?',
#  'Do you prefer blue or orange? ',
#  'Do you prefer blue or pink?',
#  'Do you prefer chipmunks or squirrels?',
#  'Do you prefer Coke or Sprite? ',
#  'Do you prefer cold drinks or hot drinks?',
#  'Do you prefer cold or hot weather?',
#  'Do you prefer crinkle-cut or straight-cut fries?',
#  'Do you prefer earbuds or headphones?',
#  'Do you prefer fall or spring?',
#  'Do you prefer fall or summer?',
#  'Do you prefer green or red?',
#  'Do you prefer Hot Cheetos or Takis?',
#  'Do you prefer Hot Coffee or Ice Coffee?',
#  'Do you prefer hot or iced tea?',
#  'Do you prefer hotdogs or burgers?',
#  'Do you prefer ketchup or ranch?',
#  'Do you prefer Mac or Windows?',
#  'Do you prefer Marvel or DC comics?',
#  'Do you prefer movies or TV shows?',
#  'Do you prefer online class or in-person class?',
#  'Pizza or tacos?',
#  'Do you prefer red or blue?',
#  'Do you prefer regular or diet soda?',
#  'Do you prefer Soccer or American Football?',
#  'Do you prefer spend your time outdoor or indoor?',
#  'Superman or batman?',
#  'Do you prefer sweet or salty foods?',
#  'Do you prefer sweet or savory food?',
#  'Do you prefer sweet or sour foods?',
#  'Do you prefer the color YELLOW or the color ORANGE?',
#  'Do you prefer the letter "M" or "N"?',
#  'Do you prefer the number 3 or the number 4?',
#  'Do you prefer to eat at ISR or IKE?',
#  'Do you prefer to have pets or no pets?',
#  'Do you prefer to listen to audio through headphones or speakers?',
#  'Do you prefer to shower at night or in the morning?',
#  'Do you prefer vegetables or fruit?',
#  'Do you pronounce caramel as "care-a-mel" or "car-mel"?',
#  'Do you pronounce Illinois "Ill-uh-noise" or "Ill-uh-noy"?',
#  'Do you pronounce the word "data" like "dah-tah" or "day-tah?"',
#  'Do you put ketchup on your hotdog?',
#  'Do you speak a language other than English?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you use Spotify or Apple Music?',
#  'Do you walk to class?',
#  'Do you wear glasses or contacts?',
#  'Does pineapple belong on pizza?',
#  'Does your first name start with a letter between A-M? (including A and M)?',
#  'Does your last name start with any letter between "A" through "L" or "M" through "Z"?',
#  'Does your UIN end with an even number or an odd number? (0 is considered an even number)',
#  'Folklore or Evermore?',
#  'Have you traveled outside of the USA this summer?',
#  'Have you ever traveled outside the USA?',
#  'Is a hotdog a sandwich?',
#  'Is math red or blue?',
#  'Is the last digit of your phone number even?',
#  'Is water wet?',
#  'Is your age an even number or an odd number?',
#  'Is your month of your birth odd or even?',
#  'Is your birthday before/on or after July 1st?',
#  'Is your day good or bad?',
#  'Is your dorm/apartment room number even?',
#  'Is your favorite color blue?',
#  'Is your favorite number even?',
#  'Is your major STEM or a humanity?',
#  'Lebron or Jordan?',
#  'Popeyes or KFC?',
#  'Was UIUC your first choice school when applying for college? ',
#  'Were you born before Feb. 14, 2005?',
#  'What came first, the chicken or the egg?',
#  'Which is the better ice cream flavor: chocolate chip or vanilla?',
#  'Which movie do you prefer Barbie or Oppenheimer?',
#  'Which number do you prefer: 49 or 62?',
#  'Which Ryan is better, Ryan Gosling or Ryan Reynolds?',
#  'which sequence do you prefer more tbge5 or pbt2l?',
#  'Who would win in a fight, Cinderella or Snow White?',
#  'Would you choose Mexican or Italian food?',
#  'Would you prefer to live an urban or rural life?',
#  'Would you rather get a book about your past or a letter revealing something about your future?',
#  'Would you rather go to an amusement park or beach?',
#  'Would you rather have a personal theme song that plays every time you enter a room, or have a spotlight follow you everywhere you go?',
#  'Would you rather have hiccups for the rest of your life or constantly feel like you have to sneeze?',
#  'Would you rather know how you die or when you die?',
#  'Would you rather never use a phone or computer again?',
#  'Would you rather take notes on a computer/tablet or paper?',
#  'In terms of Data Science, do you prefer statistics or computer science?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a day?',
#  'How many siblings do you have?',
#  'What is your phone battery percentage currently at?',
#  'How many people is the ideal number of people at a party?',
#  'What is the lowest numbered course you are taking this semester?',
#  'What is your shoe size (US size)?',
#  'From 1 to 10, how happy are you right now?',
#  'What is your first name you want us to use for you?',
#  'What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)',
#  "The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?",
#  'What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)',
#  'What do you think is the hardest major at UIUC?',
#  'What genre of music do you listen to?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'How do you respond to I-L-L?',
#  'What is your favorite game to play (either video game or IRL)?',
#  'What is your dream vacation location?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = 'Do you prefer green or red?'
analysis_column
# Out:
# 'Do you prefer green or red?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 965), "You have not loaded the correct Hello dataset"
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Do you prefer green or red?
# 0                         Green
# 1                         Green
# 2                         Green
# 3                           Red
# 4                         Green
# ..                          ...
# 960                         Red
# 961                       Green
# 962                       Green
# 963                         Red
# 964                       Green
#
# [965 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df["Do you prefer green or red?"]== "Red"]
df1
# Out:
#                        Name Section  \
# 3                  Annabel      Y05
# 5                      Sens     Y30
# 7                Joseph Kim     Y16
# 10                  Aaliyah     Y13
# 12                     Ryan     Y30
# ..                      ...     ...
# 946                    Abby       Y
# 947                Maximoff     Y33
# 949                Vihaansh     Y08
# 960  Mohammed Fatheen Ahmed     Y22
# 963                  maddax      Y2
#
#     Does your NetID ending with odd number or even number?  \
# 3                       NetID ends with an even number
# 5                       NetID ends with an even number
# 7                       NetID ends with an even number
# 10                      NetID ends with an even number
# 12                      NetID ends with an even number
# ..                                                 ...
# 946                     NetID ends with an even number
# 947                      NetID ends with an odd number
# 949                      NetID ends with an odd number
# 960                      NetID ends with an odd number
# 963                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 3                                                Heads
# 5                                                Heads
# 7                                                Heads
# 10                                               Heads
# 12                                               Heads
# ..                                                 ...
# 946                                              Heads
# 947                                              Tails
# 949                                              Heads
# 960                                              Heads
# 963                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 3                                 Tacos                    0.0
# 5                                 Tacos                    1.0
# 7                                Donuts                    1.0
# 10                               Donuts                    1.0
# 12                               Donuts                    0.0
# ..                                  ...                    ...
# 946                              Donuts                    1.0
# 947                               Tacos                    0.0
# 949                               Tacos                    1.0
# 960                              Donuts                    0.0
# 963                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 3                   Not a Freshman                         Night Person
# 5              Freshman in College                         Night Person
# 7                   Not a Freshman                         Night Person
# 10             Freshman in College                         Night Person
# 12             Freshman in College                         Night Person
# ..                             ...                                  ...
# 946            Freshman in College                         Night Person
# 947                 Not a Freshman                         Night Person
# 949                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
# 963            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 3                            Afternoon Person
# 5                              Morning Person
# 7                            Afternoon Person
# 10                           Afternoon Person
# 12                           Afternoon Person
# ..                                        ...
# 946                          Afternoon Person
# 947                          Afternoon Person
# 949                          Afternoon Person
# 960                            Morning Person
# 963                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 3                                           Illinois  ...
# 5                                           Illinois  ...
# 7                                           Illinois  ...
# 10                                          Illinois  ...
# 12                                          Illinois  ...
# ..                                               ...  ...
# 946                                         Illinois  ...
# 947                                         Illinois  ...
# 949                                     Out-of-state  ...
# 960                                         Illinois  ...
# 963                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 3                                                  Y05
# 5                                                  Y30
# 7                                                  Y16
# 10                                                 Y13
# 12                                                 Y30
# ..                                                 ...
# 946                                                  Y
# 947                                                Y33
# 949                                                Y08
# 960                                                Y22
# 963                                                 Y2
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 3                                             Moderate
# 5                                             Moderate
# 7                                                 Mild
# 10                                             Extreme
# 12                                            Moderate
# ..                                                 ...
# 946                                             strong
# 947                                             Strong
# 949                                            Extreme
# 960                                             strong
# 963                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 3                                     ISchool and LAS
# 5                                     Grainger and LAS
# 7                                                  LAS
# 10                                             iSchool
# 12                                                 LAS
# ..                                                 ...
# 946                         Data science and Business
# 947                                                LAS
# 949                               Computer Engineering
# 960                                                las
# 963                          finance with data science
#
#     What do you think is the hardest major at UIUC?  \
# 3                                 Computer science
# 5                                               ECE
# 7                                  Computer Science
# 10                                 Computer Science
# 12                                          Physics
# ..                                              ...
# 946                               Computer science
# 947                            chemical engineering
# 949                          Electrical Engineering
# 960                                              CS
# 963                                         general
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 3                              Rap or r&b                            Eminem
# 5                                Shoegaze                        Fiona Apple
# 7                              soundtrack             Ski Mask the Slump God
# 10                                    Pop                       Taylor Swift
# 12                                   Rock               Two Door Cinema Club
# ..                                    ...                                ...
# 946    anything besides rock and country                     Kendrick Lamar
# 947       hip-hop, r&b, rock, heavy metal                              JIHYO
# 949                                  Rock                             Eminem
# 960                                   rap                              Drake
# 963                                   rap                       lil uzi vert
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 3                                Snapchat                           INI
# 5                                  Twitter                        I-N-I
# 7                                Instagram                    I-N-O-I-S
# 10                                  TikTok                          INI
# 12                                 youtube                  **silence**
# ..                                     ...                          ...
# 946                             Instagram                           INI
# 947                                Twitter                           🧡💙
# 949                              Instagram                        I-N-I
# 960                                   Snap                         ini
# 963                               snapchat                          ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                             Volleyball or fortnight
# 5                                            Fall Guys
# 7    Super Smash Bros. Ultimate (Dear Karle and Wad...
# 10                                    Capture the Flag
# 12                                          Overcooked
# ..                                                 ...
# 946                                        Basketball
# 947                                               OSU!
# 949                                             Soccer
# 960                                       apex legends
# 963                                        quiet game
#
#     What is your dream vacation location?
# 3                                 Greece
# 5                                      PR
# 7                                 Nowhere
# 10                                  Spain
# 12              Grand Teton National Park
# ..                                    ...
# 946              Iceland during the fall
# 947                        Cancún, Mexico
# 949                                Norway
# 960                                europe
# 963                    middle of nowhere
#
# [405 rows x 180 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df["Do you prefer green or red?"] == "Green"]
df2
# Out:
#             Name Section  \
# 0    Prof. Karle  L1, L2
# 1     Prof. Wade  L1, L2
# 2         Andrew     Y05
# 4         Ayden      Y14
# 6          Suvan     Y22
# ..           ...     ...
# 956      Fabian      Y11
# 959         Zoe      Y19
# 961        Peter     Y09
# 962        Nyssa     Y23
# 964   CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 2                        NetID ends with an odd number
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# ..                                                 ...
# 956                      NetID ends with an odd number
# 959                     NetID ends with an even number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 2                                                Heads
# 4                                                Heads
# 6                                                Heads
# ..                                                 ...
# 956                                              Tails
# 959                                              Heads
# 961                                              Heads
# 962                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 2                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# ..                                  ...                    ...
# 956                               Tacos                    0.0
# 959                               Tacos                    1.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# ..                             ...                                  ...
# 956                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 2                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# ..                                        ...
# 956                          Afternoon Person
# 959                          Afternoon Person
# 961                            Morning Person
# 962                          Afternoon Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 2                                       Out-of-state  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# ..                                               ...  ...
# 956                                         Illinois  ...
# 959                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 2                                                  Y05
# 4                                                  Y14
# 6                                                  Y22
# ..                                                 ...
# 956                                                Y11
# 959                                                Y19
# 961                                                Y09
# 962                                                Y23
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 2                                             moderate
# 4                                               Strong
# 6                                               Strong
# ..                                                 ...
# 956                                           Extreme
# 959                                          Moderate
# 961                                             strong
# 962                                               mild
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 2                                                  LAS
# 4                                                 Gies
# 6                      Statistics and Computer Science
# ..                                                 ...
# 956                                                 IS
# 959                              School of Information
# 961                                                 CS
# 962                                                las
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 2                                                CS
# 4                                   Any engineering
# 6                              Computer Engineering
# ..                                              ...
# 956                               Computer science
# 959                          Molecular engineering
# 961                                              CS
# 962                                             ece
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 2                                     rap                               Dave
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# ..                                    ...                                ...
# 956                                   Rap                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 2                                instagram                        I-N-I
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# ..                                     ...                          ...
# 956                                      X                        I-N-I
# 959                                Tiktok                        I-N-I!
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 2                                               soccer
# 4                                           Basketball
# 6                                         20 questions
# ..                                                 ...
# 956                                          Valorant
# 959                                   Street Fighters
# 961                                     Clash of clans
# 962                                         code names
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 2                                  Hawaii
# 4                              Australia
# 6                             Switzerland
# ..                                    ...
# 956                                Greece
# 959                               Greece
# 961                               Iceland
# 962                                greece
# 964                                 Korea
#
# [548 rows x 180 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# ✏️(*The percentage of people choose Red is 405/945 = 41.97% ;
#
# The perventage of people choose Green is 548/945 = 56.79% ✏️)*

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# ✏️(*Yes, the answers is surprise me. Because people who like green are much more than red.✏️)*

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# ✏️(*No, people who like green are 56.79% - 41.97% = 14.82% more than red. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# Select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#                   Name   Section  \
# 499             Lucino       Y28
# 617              Arpit       Y35
# 209              Ramiz       Y16
# 413           Katarina       Y03
# 849             Anchal  Y21, Y11
# ..                 ...       ...
# 367             Adrian       Y24
# 607             Soumil       Y25
# 799               Wang       Y01
# 148  Venkatsaiabhishek       Y36
# 226            Lorelai       Y17
#
#     Does your NetID ending with odd number or even number?  \
# 499                     NetID ends with an even number
# 617                     NetID ends with an even number
# 209                     NetID ends with an even number
# 413                     NetID ends with an even number
# 849                     NetID ends with an even number
# ..                                                 ...
# 367                      NetID ends with an odd number
# 607                     NetID ends with an even number
# 799                      NetID ends with an odd number
# 148                     NetID ends with an even number
# 226                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 499                                              Heads
# 617                                              Heads
# 209                                              Tails
# 413                                              Tails
# 849                                              Heads
# ..                                                 ...
# 367                                              Heads
# 607                                              Heads
# 799                                              Heads
# 148                                              Heads
# 226                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 499                               Tacos                    1.0
# 617                              Donuts                    1.0
# 209                               Tacos                    1.0
# 413                               Tacos                    1.0
# 849                              Donuts                    0.0
# ..                                  ...                    ...
# 367                              Donuts                    0.0
# 607                              Donuts                    1.0
# 799                              Donuts                    0.0
# 148                              Donuts                    0.0
# 226                              Donuts                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 499            Freshman in College                         Night Person
# 617                 Not a Freshman                       Morning Person
# 209                 Not a Freshman                         Night Person
# 413                 Not a Freshman                       Morning Person
# 849                 Not a Freshman                         Night Person
# ..                             ...                                  ...
# 367            Freshman in College                       Morning Person
# 607            Freshman in College                         Night Person
# 799                 Not a Freshman                         Night Person
# 148            Freshman in College                       Morning Person
# 226            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 499                          Afternoon Person
# 617                            Morning Person
# 209                            Morning Person
# 413                            Morning Person
# 849                          Afternoon Person
# ..                                        ...
# 367                            Morning Person
# 607                          Afternoon Person
# 799                          Afternoon Person
# 148                            Morning Person
# 226                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 499                                         Illinois  ...
# 617                                     Out-of-state  ...
# 209                                         Illinois  ...
# 413                                         Illinois  ...
# 849                                         Illinois  ...
# ..                                               ...  ...
# 367                                     Out-of-state  ...
# 607                                     Out-of-state  ...
# 799                                     Out-of-state  ...
# 148                                         Illinois  ...
# 226                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 499                                                Y28
# 617                                                Y35
# 209                                                Y16
# 413                                                Y03
# 849                                           Y21, Y11
# ..                                                 ...
# 367                                                Y24
# 607                                                Y25
# 799                                                Y01
# 148                                                Y36
# 226                                                Y17
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 499                                           Moderate
# 617                                             Strong
# 209                                             Strong
# 413                                             strong
# 849                                           Moderate
# ..                                                 ...
# 367                                               none
# 607                                             strong
# 799                                            extreme
# 148                                             Strong
# 226                                           Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 499                          Accounting + Data Science
# 617                                           Grainger
# 209                                            Biology
# 413                                               ACES
# 849                                            iSchool
# ..                                                 ...
# 367                                          cs + stat
# 607                                               gies
# 799                                               Gies
# 148                                                LAS
# 226                                               Gies
#
#     What do you think is the hardest major at UIUC?  \
# 499                            Chemical Engineering
# 617                                             ECE
# 209                           Aerospace engineering
# 413                                     engineering
# 849                                Computer Science
# ..                                              ...
# 367                                              cs
# 607                               Computer Engineer
# 799                           ANY MAJOR IN GRAINGER
# 148                             Nuclear Engineering
# 226                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 499                           R&B and Rap                             Khalid
# 617                            Slow Hindi                       Arijit Singh
# 209                                   Pop                      Ariana Grande
# 413                               pop/rap                        chris brown
# 849                                   Pop                        The Weekend
# ..                                    ...                                ...
# 367                                  Jpop                            yoasobi
# 607                            All genres                         The weeknd
# 799                                   Rap                           Jay Chou
# 148                             Pop music                        The Weekend
# 226                             Indie-pop                          Vance Joy
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 499                               Snapchat                          INI
# 617                              Instagram                          INI
# 209                               Snapchat                          INI
# 413                                tik tok                          INI
# 849                              Instagram                          INI
# ..                                     ...                          ...
# 367                              instagram                          ini
# 607                              Instagram                        I-N-I
# 799                                   snap       I-N-O-I-S!!!!!!!!!!!!!
# 148                               LinkedIn                       Illini
# 226                                Youtube                        I-N-I
#
#     What is your favorite game to play (either video game or IRL)?  \
# 499                                         Mario Kart
# 617                                 Depends on my mood
# 209                                      Baldur Gate 3
# 413                                         volleyball
# 849                           I don’t play video games
# ..                                                 ...
# 367                                          minecraft
# 607                                         Basketball
# 799                                       call of duty
# 148                                         Basketball
# 226                                    Baldur's Gate 3
#
#     What is your dream vacation location?
# 499                             Santorini
# 617                              Maldives
# 209                                Hawaii
# 413                               croatia
# 849                              Bahamas
# ..                                    ...
# 367                            antarctica
# 607                                 Dubai
# 799                                  home
# 148                           Machu Pichu
# 226                   English countryside
#
# [482 rows x 180 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac = 0.5)
control
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 941  Michael     Y29                     NetID ends with an even number
# 309   Olivia     Y09                      NetID ends with an odd number
# 774    Jason     Y16                      NetID ends with an odd number
# 229   Thomas     Y13                     NetID ends with an even number
# 700    Kevin     Y29                     NetID ends with an even number
# ..       ...     ...                                                ...
# 101     Junu     Y02                     NetID ends with an even number
# 60     Rylan     Y13                      NetID ends with an odd number
# 388   Trevor     Y28                      NetID ends with an odd number
# 216  Kaixuan     Y17                      NetID ends with an odd number
# 790   Mukund     Y18                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 941                                              Heads
# 309                                              Heads
# 774                                              Tails
# 229                                              Heads
# 700                                              Heads
# ..                                                 ...
# 101                                              Heads
# 60                                               Heads
# 388                                              Tails
# 216                                              Tails
# 790                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 941                              Donuts                    1.0
# 309                               Tacos                    0.0
# 774                               Tacos                    1.0
# 229                               Tacos                    0.0
# 700                              Donuts                    0.0
# ..                                  ...                    ...
# 101                               Tacos                    0.0
# 60                                Tacos                    1.0
# 388                               Tacos                    0.0
# 216                               Tacos                    0.0
# 790                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 941            Freshman in College                         Night Person
# 309            Freshman in College                         Night Person
# 774                 Not a Freshman                         Night Person
# 229                 Not a Freshman                         Night Person
# 700            Freshman in College                         Night Person
# ..                             ...                                  ...
# 101                 Not a Freshman                         Night Person
# 60                  Not a Freshman                         Night Person
# 388                 Not a Freshman                         Night Person
# 216            Freshman in College                       Morning Person
# 790            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 941                          Afternoon Person
# 309                          Afternoon Person
# 774                          Afternoon Person
# 229                          Afternoon Person
# 700                          Afternoon Person
# ..                                        ...
# 101                          Afternoon Person
# 60                           Afternoon Person
# 388                          Afternoon Person
# 216                            Morning Person
# 790                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 941                                     Out-of-state  ...
# 309                                         Illinois  ...
# 774                                         Illinois  ...
# 229                                         Illinois  ...
# 700                                         Illinois  ...
# ..                                               ...  ...
# 101                                     Out-of-state  ...
# 60                                          Illinois  ...
# 388                                         Illinois  ...
# 216                                     Out-of-state  ...
# 790                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 941                                                Y29
# 309                                                Y09
# 774                                                Y16
# 229                                                Y13
# 700                                                Y29
# ..                                                 ...
# 101                                                Y02
# 60                                                 Y13
# 388                                                Y28
# 216                                                Y17
# 790                                                Y18
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 941                                             Strong
# 309                                             strong
# 774                                           Moderate
# 229                                          Moderate
# 700                                           Moderate
# ..                                                 ...
# 101                                             strong
# 60                                              strong
# 388                                               Mild
# 216                                             strong
# 790                                           Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 941                                               Gies
# 309                                               gies
# 774                                               Gies
# 229                                                LAS
# 700                                                LAS
# ..                                                 ...
# 101                     Computer Science and Economics
# 60                                             iSchool
# 388                           Gies College of Business
# 216                                                Las
# 790                          Gies College of Business
#
#     What do you think is the hardest major at UIUC?  \
# 941                                              CS
# 309                                     engineering
# 774                                             ECE
# 229                            Nuclear Engineering
# 700                          Electrical Engineering
# ..                                              ...
# 101                             Engineering Physics
# 60                           Biomedical Engineering
# 388                                         Physics
# 216                                              ee
# 790                               Computer Science
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 941                                   Rap                       Lil Uzi Vert
# 309                                   edm                           kid cudi
# 774                                   Rap                           Lil Baby
# 229                                   Pop                           Bren Joy
# 700                                   Pop                       Charlie Puth
# ..                                    ...                                ...
# 101                               Hip-hop                              Kanye
# 60                          Electro Swing                          TheFatRat
# 388                               Country                         Zach Bryan
# 216                                   pop                         Bruno Mars
# 790                                   Rap                      Travis Scott
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 941                                 TikTok                          INI
# 309                               snapchat                        I-N-I
# 774                              Instagram                          INI
# 229                             Instagram                           INI
# 700                              Instagram                          INI
# ..                                     ...                          ...
# 101                               Linkedin                          INI
# 60                                 Discord                        I-N-I
# 388                               Snapchat                        I-N-I
# 216                               bilibili                        I-N-I
# 790                              Snapchat                         Sorry
#
#     What is your favorite game to play (either video game or IRL)?  \
# 941                                           Lacrosse
# 309                                              Sorry
# 774                                              Poker
# 229                                      Hollow knight
# 700                                          Minecraft
# ..                                                 ...
# 101                                              GTA 5
# 60                                           Minecraft
# 388                                               Golf
# 216                                             Naroto
# 790                                         Basketball
#
#     What is your dream vacation location?
# 941                                 Italy
# 309                                 italy
# 774                                 Beach
# 229                                 Japan
# 700                                 Paris
# ..                                    ...
# 101                                Hawaii
# 60                                Boracay
# 388                                 Kenya
# 216                       northern Europe
# 790                               Greece
#
# [482 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#                   Name Section  \
# 2               Andrew     Y05
# 3             Annabel      Y05
# 12                Ryan     Y30
# 15             Michael     Y03
# 16              binchi     Y35
# ..                 ...     ...
# 933             Daniel     Y32
# 941            Michael     Y29
# 944             Mahdia     Y06
# 951  Anuraag Aravindan     Y30
# 964         CA Sangjun     Y23
#
#     Does your NetID ending with odd number or even number?  \
# 2                        NetID ends with an odd number
# 3                       NetID ends with an even number
# 12                      NetID ends with an even number
# 15                      NetID ends with an even number
# 16                       NetID ends with an odd number
# ..                                                 ...
# 933                      NetID ends with an odd number
# 941                     NetID ends with an even number
# 944                     NetID ends with an even number
# 951                     NetID ends with an even number
# 964                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 2                                                Heads
# 3                                                Heads
# 12                                               Heads
# 15                                               Heads
# 16                                               Tails
# ..                                                 ...
# 933                                              Heads
# 941                                              Heads
# 944                                              Heads
# 951                                              Heads
# 964                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 2                                 Tacos                    1.0
# 3                                 Tacos                    0.0
# 12                               Donuts                    0.0
# 15                                Tacos                    0.0
# 16                                Tacos                    0.0
# ..                                  ...                    ...
# 933                              Donuts                    0.0
# 941                              Donuts                    1.0
# 944                               Tacos                    1.0
# 951                              Donuts                    0.0
# 964                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 2              Freshman in College                         Night Person
# 3                   Not a Freshman                         Night Person
# 12             Freshman in College                         Night Person
# 15                  Not a Freshman                         Night Person
# 16             Freshman in College                       Morning Person
# ..                             ...                                  ...
# 933                 Not a Freshman                         Night Person
# 941            Freshman in College                         Night Person
# 944                 Not a Freshman                         Night Person
# 951            Freshman in College                       Morning Person
# 964                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 2                            Afternoon Person
# 3                            Afternoon Person
# 12                           Afternoon Person
# 15                           Afternoon Person
# 16                             Morning Person
# ..                                        ...
# 933                          Afternoon Person
# 941                          Afternoon Person
# 944                          Afternoon Person
# 951                            Morning Person
# 964                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 2                                       Out-of-state  ...
# 3                                           Illinois  ...
# 12                                          Illinois  ...
# 15                                          Illinois  ...
# 16                                      Out-of-state  ...
# ..                                               ...  ...
# 933                                         Illinois  ...
# 941                                     Out-of-state  ...
# 944                                         Illinois  ...
# 951                                     Out-of-state  ...
# 964                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 2                                                  Y05
# 3                                                  Y05
# 12                                                 Y30
# 15                                                 Y03
# 16                                                 Y35
# ..                                                 ...
# 933                                                Y32
# 941                                                Y29
# 944                                                Y06
# 951                                                Y30
# 964                                                Y23
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 2                                             moderate
# 3                                             Moderate
# 12                                            Moderate
# 15                                             Extreme
# 16                                                mild
# ..                                                 ...
# 933                                           Moderate
# 941                                             Strong
# 944                                           moderate
# 951                                             strong
# 964                                               Mild
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 2                                                  LAS
# 3                                     ISchool and LAS
# 12                                                 LAS
# 15                                                 LAS
# 16                                                math
# ..                                                 ...
# 933                                                LAS
# 941                                               Gies
# 944                               Information sciences
# 951                                                LAS
# 964                                         Statistics
#
#     What do you think is the hardest major at UIUC?  \
# 2                                                CS
# 3                                 Computer science
# 12                                          Physics
# 15                           Electrical Engineering
# 16                                             math
# ..                                              ...
# 933                            Chemical Engineering
# 941                                              CS
# 944                                computer science
# 951                                         Physics
# 964                                     Engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 2                                     rap                               Dave
# 3                              Rap or r&b                            Eminem
# 12                                   Rock               Two Door Cinema Club
# 15                             Indie rock                           Pavement
# 16                                    R&B                                jay
# ..                                    ...                                ...
# 933                               Country                      Morgan Wallen
# 941                                   Rap                       Lil Uzi Vert
# 944                                 indie                       taylor swift
# 951                            Everything                              drake
# 964                                   RnB                      Wave to Earth
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 2                                instagram                        I-N-I
# 3                                Snapchat                           INI
# 12                                 youtube                  **silence**
# 15                               Instagram                        I-N-I
# 16                                     ins                          ini
# ..                                     ...                          ...
# 933                               Snapchat                        I-N-I
# 941                                 TikTok                          INI
# 944                              instagram                          INI
# 951                              Instagram                          INI
# 964                              Instagram                          INI
#
#     What is your favorite game to play (either video game or IRL)?  \
# 2                                               soccer
# 3                             Volleyball or fortnight
# 12                                          Overcooked
# 15                                            Baseball
# 16                                                FIFA
# ..                                                 ...
# 933                                             Hockey
# 941                                           Lacrosse
# 944                                          beer pong
# 951                                             tennis
# 964                                     Clash of Clans
#
#     What is your dream vacation location?
# 2                                  Hawaii
# 3                                 Greece
# 12              Grand Teton National Park
# 15                                 France
# 16                                     LA
# ..                                    ...
# 933                               Bahamas
# 941                                 Italy
# 944                                  cabo
# 951                             australia
# 964                                 Korea
#
# [238 rows x 180 columns]

# %% [markdown]
# **Q: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# ✏️(*Becuase frac is randomly select fraction of rows. It's really common that the people is include in both group in the 2 of the randomly select.✏️)*

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index. isin(treatment. index) ]
control
# Out:
#                        Name Section  \
# 0               Prof. Karle  L1, L2
# 1                Prof. Wade  L1, L2
# 4                    Ayden      Y14
# 6                     Suvan     Y22
# 9           Pradnyan Khodke     Y24
# ..                      ...     ...
# 959                    Zoe      Y19
# 960  Mohammed Fatheen Ahmed     Y22
# 961                   Peter     Y09
# 962                   Nyssa     Y23
# 963                  maddax      Y2
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 1                                                  NaN
# 4                       NetID ends with an even number
# 6                       NetID ends with an even number
# 9                        NetID ends with an odd number
# ..                                                 ...
# 959                     NetID ends with an even number
# 960                      NetID ends with an odd number
# 961                     NetID ends with an even number
# 962                      NetID ends with an odd number
# 963                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 1                                                Heads
# 4                                                Heads
# 6                                                Heads
# 9                                                Heads
# ..                                                 ...
# 959                                              Heads
# 960                                              Heads
# 961                                              Heads
# 962                                              Heads
# 963                                              Tails
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 1                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 6                                Donuts                    1.0
# 9                                 Tacos                    1.0
# ..                                  ...                    ...
# 959                               Tacos                    1.0
# 960                              Donuts                    0.0
# 961                               Tacos                    1.0
# 962                               Tacos                    1.0
# 963                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 1                   Not a Freshman                         Night Person
# 4              Freshman in College                         Night Person
# 6              Freshman in College                         Night Person
# 9                   Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 959            Freshman in College                         Night Person
# 960            Freshman in College                       Morning Person
# 961                 Not a Freshman                       Morning Person
# 962            Freshman in College                         Night Person
# 963            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 1                            Afternoon Person
# 4                              Morning Person
# 6                            Afternoon Person
# 9                              Morning Person
# ..                                        ...
# 959                          Afternoon Person
# 960                            Morning Person
# 961                            Morning Person
# 962                          Afternoon Person
# 963                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 1                                                NaN  ...
# 4                                           Illinois  ...
# 6                                           Illinois  ...
# 9                                           Illinois  ...
# ..                                               ...  ...
# 959                                         Illinois  ...
# 960                                         Illinois  ...
# 961                                     Out-of-state  ...
# 962                                         Illinois  ...
# 963                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 1                                               L1, L2
# 4                                                  Y14
# 6                                                  Y22
# 9                                                  Y24
# ..                                                 ...
# 959                                                Y19
# 960                                                Y22
# 961                                                Y09
# 962                                                Y23
# 963                                                 Y2
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 1                                             Moderate
# 4                                               Strong
# 6                                               Strong
# 9                                               Strong
# ..                                                 ...
# 959                                          Moderate
# 960                                             strong
# 961                                             strong
# 962                                               mild
# 963                                            extreme
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 1                                             Grainger
# 4                                                 Gies
# 6                      Statistics and Computer Science
# 9                                                  LAS
# ..                                                 ...
# 959                              School of Information
# 960                                                las
# 961                                                 CS
# 962                                                las
# 963                          finance with data science
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 1                                           Physics
# 4                                   Any engineering
# 6                              Computer Engineering
# 9                                               ECE
# ..                                              ...
# 959                          Molecular engineering
# 960                                              CS
# 961                                              CS
# 962                                             ece
# 963                                         general
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 1                             Pop and EDM                       Taylor Swift
# 4                               Indie pop                      The Lumineers
# 6                                 Hip hop                        Don toliver
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# ..                                    ...                                ...
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
# 960                                   rap                              Drake
# 961                                  Jazz                                 Ye
# 962                                   pop                       taylor swift
# 963                                   rap                       lil uzi vert
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 1                                  YouTube                        I-N-I
# 4                                 Snapchat                          INI
# 6                                   Tiktok                         Ini
# 9                                        X                        I-N-I
# ..                                     ...                          ...
# 959                                Tiktok                        I-N-I!
# 960                                   Snap                         ini
# 961                                     QQ                         illi
# 962                                twitter                          INI
# 963                               snapchat                          ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 1                                             Factorio
# 4                                           Basketball
# 6                                         20 questions
# 9                                           Basketball
# ..                                                 ...
# 959                                   Street Fighters
# 960                                       apex legends
# 961                                     Clash of clans
# 962                                         code names
# 963                                        quiet game
#
#     What is your dream vacation location?
# 0                            The Maldives
# 1                               Mountains
# 4                              Australia
# 6                             Switzerland
# 9                                    Asia
# ..                                    ...
# 959                               Greece
# 960                                europe
# 961                               Iceland
# 962                                greece
# 963                    middle of nowhere
#
# [483 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`"
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`"
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:
# ...feel free to add extra "Code" cells here if needed.

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q: Which group where you in -- treatment or control?**

# %% [markdown]
# *(✏️ Edit this cell to replace this text wth your answer. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac = 0.5)
df1_treatment
# Out:
#         Name Section Does your NetID ending with odd number or even number?  \
# 122     Ryan     Y31                     NetID ends with an even number
# 72      Alma     Y23                     NetID ends with an even number
# 637   Andrew     Y02                     NetID ends with an even number
# 861   Weihao     Y34                     NetID ends with an even number
# 35    Thomas     Y11                      NetID ends with an odd number
# ..       ...     ...                                                ...
# 880  Michael     Y16                     NetID ends with an even number
# 268   Steven     Y20                      NetID ends with an odd number
# 168    Diego     Y10                     NetID ends with an even number
# 551   Thomas     Y01                      NetID ends with an odd number
# 638  Camille     Y04                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 122                                              Heads
# 72                                               Heads
# 637                                              Heads
# 861                                              Heads
# 35                                               Heads
# ..                                                 ...
# 880                                              Heads
# 268                                              Heads
# 168                                              Heads
# 551                                              Heads
# 638                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 122                              Donuts                    0.0
# 72                               Donuts                    0.0
# 637                               Tacos                    1.0
# 861                               Tacos                    1.0
# 35                                Tacos                    1.0
# ..                                  ...                    ...
# 880                               Tacos                    1.0
# 268                               Tacos                    1.0
# 168                               Tacos                    1.0
# 551                               Tacos                    1.0
# 638                               Tacos                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 122            Freshman in College                       Morning Person
# 72             Freshman in College                         Night Person
# 637                 Not a Freshman                         Night Person
# 861                 Not a Freshman                         Night Person
# 35                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 880            Freshman in College                         Night Person
# 268            Freshman in College                       Morning Person
# 168            Freshman in College                         Night Person
# 551                 Not a Freshman                         Night Person
# 638                 Not a Freshman                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 122                            Morning Person
# 72                           Afternoon Person
# 637                          Afternoon Person
# 861                          Afternoon Person
# 35                           Afternoon Person
# ..                                        ...
# 880                          Afternoon Person
# 268                          Afternoon Person
# 168                          Afternoon Person
# 551                            Morning Person
# 638                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 122                                         Illinois  ...
# 72                                          Illinois  ...
# 637                                         Illinois  ...
# 861                                         Illinois  ...
# 35                                          Illinois  ...
# ..                                               ...  ...
# 880                                     Out-of-state  ...
# 268                                         Illinois  ...
# 168                                         Illinois  ...
# 551                                         Illinois  ...
# 638                                     Out-of-state  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 122                                                Y31
# 72                                                 Y23
# 637                                                Y02
# 861                                                Y34
# 35                                                 Y11
# ..                                                 ...
# 880                                                Y16
# 268                                                Y20
# 168                                                Y10
# 551                                                Y01
# 638                                                Y04
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 122                                           Moderate
# 72                                                Mild
# 637                                               Mild
# 861                                                NaN
# 35                                              strong
# ..                                                 ...
# 880                                           moderate
# 268                                           moderate
# 168                                                NaN
# 551                                               mild
# 638                                                NaN
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 122                                            iSchool
# 72                                                Gies
# 637                                       Data Science
# 861                                                NaN
# 35                                          statistics
# ..                                                 ...
# 880                                                LAS
# 268                                            iSchool
# 168                                Information Science
# 551                           Gies college of business
# 638                                                NaN
#
#     What do you think is the hardest major at UIUC?  \
# 122                                              CS
# 72                                      Engineering
# 637                                              CS
# 861                                             NaN
# 35                           electrical engineering
# ..                                              ...
# 880                                computer science
# 268                  Physics or Nuclear Engineering
# 168                                         Physics
# 551                          electrical engineering
# 638                                             NaN
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 122                                   Pop                           Surfaces
# 72                Heavy Metal and Dubstep                      Sullivan King
# 637                                   Rap                           Zack Fox
# 861                                   NaN                                NaN
# 35                                    pop                        Post Malone
# ..                                    ...                                ...
# 880                         Popular music                          Joker Xue
# 268                             Jazz/blue                      Frank Sinatra
# 168                                  Jazz                       Hall & Oates
# 551                                  rock                         Kanye West
# 638                                   NaN                                NaN
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 122                                YouTube                       Innie!
# 72                                 Discord                    I don’t.
# 637                              Instagram                         INI!
# 861                                    NaN                          NaN
# 35                               instagram                          INI
# ..                                     ...                          ...
# 880                                 wechat                        I-N-I
# 268                        Youtube/Discord                        I-N-I
# 168                                 TikTok                          INI
# 551                              instagram                    I-N-I!!!!
# 638                                    NaN                          NaN
#
#     What is your favorite game to play (either video game or IRL)?  \
# 122                                          Minecraft
# 72                                              Roblox
# 637                                         Basketball
# 861                                                NaN
# 35                                          smash bros
# ..                                                 ...
# 880                                               csgo
# 268                                               both
# 168                                              Chess
# 551                                  golf in real life
# 638                                                NaN
#
#     What is your dream vacation location?
# 122                                Hawaii
# 72                                   Home
# 637                            California
# 861                                   NaN
# 35                                   city
# ..                                    ...
# 880                                Hawaii
# 268                                   NaN
# 168                           French Alps
# 551                                 Spain
# 638                                   NaN
#
# [202 rows x 180 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index. isin(df1_treatment. index) ]
df1_control
# Out:
#                        Name Section  \
# 5                      Sens     Y30
# 10                  Aaliyah     Y13
# 12                     Ryan     Y30
# 19                   Lauren     Y03
# 27                   Zikora     Y31
# ..                      ...     ...
# 933                  Daniel     Y32
# 938                    Yuqi     Y02
# 946                    Abby       Y
# 947                Maximoff     Y33
# 960  Mohammed Fatheen Ahmed     Y22
#
#     Does your NetID ending with odd number or even number?  \
# 5                       NetID ends with an even number
# 10                      NetID ends with an even number
# 12                      NetID ends with an even number
# 19                      NetID ends with an even number
# 27                       NetID ends with an odd number
# ..                                                 ...
# 933                      NetID ends with an odd number
# 938                     NetID ends with an even number
# 946                     NetID ends with an even number
# 947                      NetID ends with an odd number
# 960                      NetID ends with an odd number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 5                                                Heads
# 10                                               Heads
# 12                                               Heads
# 19                                               Heads
# 27                                               Tails
# ..                                                 ...
# 933                                              Heads
# 938                                              Heads
# 946                                              Heads
# 947                                              Tails
# 960                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 5                                 Tacos                    1.0
# 10                               Donuts                    1.0
# 12                               Donuts                    0.0
# 19                                Tacos                    0.0
# 27                                  NaN                    1.0
# ..                                  ...                    ...
# 933                              Donuts                    0.0
# 938                              Donuts                    1.0
# 946                              Donuts                    1.0
# 947                               Tacos                    0.0
# 960                              Donuts                    0.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 5              Freshman in College                         Night Person
# 10             Freshman in College                         Night Person
# 12             Freshman in College                         Night Person
# 19                  Not a Freshman                         Night Person
# 27                  Not a Freshman                                  NaN
# ..                             ...                                  ...
# 933                 Not a Freshman                         Night Person
# 938            Freshman in College                         Night Person
# 946            Freshman in College                         Night Person
# 947                 Not a Freshman                         Night Person
# 960            Freshman in College                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 5                              Morning Person
# 10                           Afternoon Person
# 12                           Afternoon Person
# 19                             Morning Person
# 27                                        NaN
# ..                                        ...
# 933                          Afternoon Person
# 938                          Afternoon Person
# 946                          Afternoon Person
# 947                          Afternoon Person
# 960                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 5                                           Illinois  ...
# 10                                          Illinois  ...
# 12                                          Illinois  ...
# 19                                          Illinois  ...
# 27                                               NaN  ...
# ..                                               ...  ...
# 933                                         Illinois  ...
# 938                                     Out-of-state  ...
# 946                                         Illinois  ...
# 947                                         Illinois  ...
# 960                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 5                                                  Y30
# 10                                                 Y13
# 12                                                 Y30
# 19                                                 Y03
# 27                                                 Y31
# ..                                                 ...
# 933                                                Y32
# 938                                                Y02
# 946                                                  Y
# 947                                                Y33
# 960                                                Y22
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 5                                             Moderate
# 10                                             Extreme
# 12                                            Moderate
# 19                                             Strong
# 27                                             Extreme
# ..                                                 ...
# 933                                           Moderate
# 938                                             strong
# 946                                             strong
# 947                                             Strong
# 960                                             strong
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 5                                     Grainger and LAS
# 10                                             iSchool
# 12                                                 LAS
# 19                                                 LAS
# 27                                            Grainger
# ..                                                 ...
# 933                                                LAS
# 938                                                NYU
# 946                         Data science and Business
# 947                                                LAS
# 960                                                las
#
#     What do you think is the hardest major at UIUC?  \
# 5                                               ECE
# 10                                 Computer Science
# 12                                          Physics
# 19                                     Engineering
# 27                                          ECE 374
# ..                                              ...
# 933                            Chemical Engineering
# 938                                              CS
# 946                               Computer science
# 947                            chemical engineering
# 960                                              CS
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 5                                Shoegaze                        Fiona Apple
# 10                                    Pop                       Taylor Swift
# 12                                   Rock               Two Door Cinema Club
# 19                                    All                                N/a
# 27                                   Rnb                         Jaden Smith
# ..                                    ...                                ...
# 933                               Country                      Morgan Wallen
# 938                                  trap                         Sijian Liu
# 946    anything besides rock and country                     Kendrick Lamar
# 947       hip-hop, r&b, rock, heavy metal                              JIHYO
# 960                                   rap                              Drake
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 5                                  Twitter                        I-N-I
# 10                                  TikTok                          INI
# 12                                 youtube                  **silence**
# 19                                 Tik Tok                        I-N-I
# 27                                  Tiktok                         Ini
# ..                                     ...                          ...
# 933                               Snapchat                        I-N-I
# 938                                We Chat                 I don't know
# 946                             Instagram                           INI
# 947                                Twitter                           🧡💙
# 960                                   Snap                         ini
#
#     What is your favorite game to play (either video game or IRL)?  \
# 5                                            Fall Guys
# 10                                    Capture the Flag
# 12                                          Overcooked
# 19                                                 N/a
# 27                                       Forza Horizon
# ..                                                 ...
# 933                                             Hockey
# 938                                              CS:GO
# 946                                        Basketball
# 947                                               OSU!
# 960                                       apex legends
#
#     What is your dream vacation location?
# 5                                      PR
# 10                                  Spain
# 12              Grand Teton National Park
# 19                                  Japan
# 27                                 Europe
# ..                                    ...
# 933                               Bahamas
# 938                             Chongqing
# 946              Iceland during the fall
# 947                        Cancún, Mexico
# 960                                europe
#
# [203 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac = 0.5)
df2_treatment
# Out:
#         Name   Section Does your NetID ending with odd number or even number?  \
# 611  Chatora       Y07                     NetID ends with an even number
# 571    Paige       Y32                     NetID ends with an even number
# 309   Olivia       Y09                      NetID ends with an odd number
# 115  Timothy       Y34                     NetID ends with an even number
# 141    Sarah       Y32                     NetID ends with an even number
# ..       ...       ...                                                ...
# 132     Rhea       Y34                     NetID ends with an even number
# 787    Kelly       Y23                     NetID ends with an even number
# 904    Subbu       Y20                     NetID ends with an even number
# 812  Michael       Y13                      NetID ends with an odd number
# 842   CA Mia  Y05, Y13                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 611                                              Tails
# 571                                              Tails
# 309                                              Heads
# 115                                              Tails
# 141                                              Heads
# ..                                                 ...
# 132                                              Heads
# 787                                              Heads
# 904                                              Heads
# 812                                              Heads
# 842                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 611                               Tacos                    1.0
# 571                               Tacos                    1.0
# 309                               Tacos                    0.0
# 115                               Tacos                    1.0
# 141                               Tacos                    1.0
# ..                                  ...                    ...
# 132                               Tacos                    0.0
# 787                               Tacos                    1.0
# 904                               Tacos                    1.0
# 812                               Tacos                    0.0
# 842                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 611                 Not a Freshman                         Night Person
# 571                 Not a Freshman                       Morning Person
# 309            Freshman in College                         Night Person
# 115            Freshman in College                         Night Person
# 141                 Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 132            Freshman in College                         Night Person
# 787                 Not a Freshman                       Morning Person
# 904            Freshman in College                       Morning Person
# 812                 Not a Freshman                         Night Person
# 842                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 611                          Afternoon Person
# 571                            Morning Person
# 309                          Afternoon Person
# 115                          Afternoon Person
# 141                            Morning Person
# ..                                        ...
# 132                          Afternoon Person
# 787                            Morning Person
# 904                            Morning Person
# 812                          Afternoon Person
# 842                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 611                                         Illinois  ...
# 571                                         Illinois  ...
# 309                                         Illinois  ...
# 115                                         Illinois  ...
# 141                                         Illinois  ...
# ..                                               ...  ...
# 132                                     Out-of-state  ...
# 787                                     Out-of-state  ...
# 904                                         Illinois  ...
# 812                                         Illinois  ...
# 842                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 611                                                Y07
# 571                                                Y32
# 309                                                Y09
# 115                                                Y34
# 141                                                Y32
# ..                                                 ...
# 132                                                Y34
# 787                                                Y23
# 904                                                Y20
# 812                                                Y13
# 842                                           Y05, Y13
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 611                                           moderate
# 571                                           Moderate
# 309                                             strong
# 115                                             strong
# 141                                            Extreme
# ..                                                 ...
# 132                                           Moderate
# 787                                             Strong
# 904                                             Strong
# 812                                             Strong
# 842                                           Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 611                              Fine and applied arts
# 571                                               Gies
# 309                                               gies
# 115                                           Business
# 141                             Applied Health Science
# ..                                                 ...
# 132                                               Gies
# 787                                                LAS
# 904                                                LAS
# 812                                                AHS
# 842                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 611                                        engineer
# 571                                       Chemistry
# 309                                     engineering
# 115                                Computer Science
# 141                                              CS
# ..                                              ...
# 132                          Aerospace engineering
# 787                                Computer Science
# 904                            Computer Engineering
# 812                                Computer Science
# 842                                         Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 611                                   r&b                        post malone
# 571                                   Pop                     Olivia Rodrigo
# 309                                   edm                           kid cudi
# 115                               Pop/R&B                             Khalid
# 141                                   R&B                       Brent Faiyaz
# ..                                    ...                                ...
# 132                                   Pop                              Vinyl
# 787                               Hip hop                             Halsey
# 904                                   Pop                            Anirudh
# 812                                   Rap                           Babytron
# 842                                   Pop                       Taylor Swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 611                              tick tock                        call
# 571                              Instagram                        I-N-I
# 309                               snapchat                        I-N-I
# 115                              Instagram                          INI
# 141                               Snapchat                        I-N-I
# ..                                     ...                          ...
# 132                              Instagram                        I-N-I
# 787                              Instagram                        I-N-I
# 904                              Instagram                          INI
# 812                                Twitter                        I-N-I
# 842                                Twitter                       I-N-I!
#
#     What is your favorite game to play (either video game or IRL)?  \
# 611                                               maze
# 571                                         Mario Kart
# 309                                              Sorry
# 115                                           Valorant
# 141                                         Volleyball
# ..                                                 ...
# 132                                           Napolean
# 787                                          Homescape
# 904                                              Chess
# 812                                         Pickleball
# 842                                              Taboo
#
#     What is your dream vacation location?
# 611                                 italy
# 571                                Greece
# 309                                 italy
# 115                                 Japan
# 141                           Philippines
# ..                                    ...
# 132                                 Japan
# 787                                Greece
# 904                                Alaska
# 812                                Hawaii
# 842                             Barcelona
#
# [274 rows x 180 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[ ~df2.index. isin(df2_treatment. index) ]
df2_control
# Out:
#                 Name Section  \
# 0        Prof. Karle  L1, L2
# 2             Andrew     Y05
# 4             Ayden      Y14
# 8              Sarah     Y36
# 9    Pradnyan Khodke     Y24
# ..               ...     ...
# 953            Laura     Y28
# 954            Junyu  \t Y36
# 955         lijiajin     Y01
# 956          Fabian      Y11
# 959             Zoe      Y19
#
#     Does your NetID ending with odd number or even number?  \
# 0                        NetID ends with an odd number
# 2                        NetID ends with an odd number
# 4                       NetID ends with an even number
# 8                        NetID ends with an odd number
# 9                        NetID ends with an odd number
# ..                                                 ...
# 953                     NetID ends with an even number
# 954                      NetID ends with an odd number
# 955                      NetID ends with an odd number
# 956                      NetID ends with an odd number
# 959                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 0                                                Heads
# 2                                                Heads
# 4                                                Heads
# 8                                                Heads
# 9                                                Heads
# ..                                                 ...
# 953                                              Heads
# 954                                              Heads
# 955                                              Heads
# 956                                              Tails
# 959                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 0                                 Tacos                    0.0
# 2                                 Tacos                    1.0
# 4                                Donuts                    1.0
# 8                                Donuts                    0.0
# 9                                 Tacos                    1.0
# ..                                  ...                    ...
# 953                              Donuts                    0.0
# 954                               Tacos                    1.0
# 955                              Donuts                    0.0
# 956                               Tacos                    0.0
# 959                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 0                   Not a Freshman                         Night Person
# 2              Freshman in College                         Night Person
# 4              Freshman in College                         Night Person
# 8              Freshman in College                       Morning Person
# 9                   Not a Freshman                       Morning Person
# ..                             ...                                  ...
# 953            Freshman in College                         Night Person
# 954            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 956                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 0                            Afternoon Person
# 2                            Afternoon Person
# 4                              Morning Person
# 8                              Morning Person
# 9                              Morning Person
# ..                                        ...
# 953                          Afternoon Person
# 954                          Afternoon Person
# 955                            Morning Person
# 956                          Afternoon Person
# 959                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 0                                           Illinois  ...
# 2                                       Out-of-state  ...
# 4                                           Illinois  ...
# 8                                           Illinois  ...
# 9                                           Illinois  ...
# ..                                               ...  ...
# 953                                     Out-of-state  ...
# 954                                     Out-of-state  ...
# 955                                     Out-of-state  ...
# 956                                         Illinois  ...
# 959                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 0                                               L1, L2
# 2                                                  Y05
# 4                                                  Y14
# 8                                                  Y36
# 9                                                  Y24
# ..                                                 ...
# 953                                                Y28
# 954                                             \t Y36
# 955                                                Y01
# 956                                                Y11
# 959                                                Y19
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 0                                             moderate
# 2                                             moderate
# 4                                               Strong
# 8                                               Strong
# 9                                               Strong
# ..                                                 ...
# 953                                             Strong
# 954                                             strong
# 955                                             strong
# 956                                           Extreme
# 959                                          Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 0                                           Statistics
# 2                                                  LAS
# 4                                                 Gies
# 8                                              iSchool
# 9                                                  LAS
# ..                                                 ...
# 953                                               Gies
# 954                               information science
# 955                                                 cs
# 956                                                 IS
# 959                              School of Information
#
#     What do you think is the hardest major at UIUC?  \
# 0                             Anything in GRAINGER!
# 2                                                CS
# 4                                   Any engineering
# 8                                  Computer Science
# 9                                               ECE
# ..                                              ...
# 953                                    Engineering
# 954                                              CS
# 955                                              cs
# 956                               Computer science
# 959                          Molecular engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 0                           TAYLOR SWIFT!                       Taylor Swift
# 2                                     rap                               Dave
# 4                               Indie pop                      The Lumineers
# 8                                   Indie                       Taylor Swift
# 9              Hip hop, R&B, Indie, Rock,                  Tyler The Creator
# ..                                    ...                                ...
# 953                                   Pop                         Eason Chen
# 954                                Hiphop                Tyler, The Creator
# 955                                   sad                           Lana Ray
# 956                                   Rap                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 0                                Instagram                        I-N-I
# 2                                instagram                        I-N-I
# 4                                 Snapchat                          INI
# 8                                Instagram                        I-N-I
# 9                                        X                        I-N-I
# ..                                     ...                          ...
# 953                              Instagram                        I-N-I
# 954                                    Ins                         good
# 955                                    ins                        I-N-N
# 956                                      X                        I-N-I
# 959                                Tiktok                        I-N-I!
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                Any type of card game
# 2                                               soccer
# 4                                           Basketball
# 8                                                  Uno
# 9                                           Basketball
# ..                                                 ...
# 953                                               2048
# 954                                             Soccer
# 955                                           valorant
# 956                                          Valorant
# 959                                   Street Fighters
#
#     What is your dream vacation location?
# 0                            The Maldives
# 2                                  Hawaii
# 4                              Australia
# 8                                  Taiwan
# 9                                    Asia
# ..                                    ...
# 953                                europe
# 954                          Sanya, China
# 955                               finland
# 956                                Greece
# 959                               Greece
#
# [274 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd. concat( [df1_treatment, df2_treatment])
treatment
# Out:
#         Name   Section Does your NetID ending with odd number or even number?  \
# 122     Ryan       Y31                     NetID ends with an even number
# 72      Alma       Y23                     NetID ends with an even number
# 637   Andrew       Y02                     NetID ends with an even number
# 861   Weihao       Y34                     NetID ends with an even number
# 35    Thomas       Y11                      NetID ends with an odd number
# ..       ...       ...                                                ...
# 132     Rhea       Y34                     NetID ends with an even number
# 787    Kelly       Y23                     NetID ends with an even number
# 904    Subbu       Y20                     NetID ends with an even number
# 812  Michael       Y13                      NetID ends with an odd number
# 842   CA Mia  Y05, Y13                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 122                                              Heads
# 72                                               Heads
# 637                                              Heads
# 861                                              Heads
# 35                                               Heads
# ..                                                 ...
# 132                                              Heads
# 787                                              Heads
# 904                                              Heads
# 812                                              Heads
# 842                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 122                              Donuts                    0.0
# 72                               Donuts                    0.0
# 637                               Tacos                    1.0
# 861                               Tacos                    1.0
# 35                                Tacos                    1.0
# ..                                  ...                    ...
# 132                               Tacos                    0.0
# 787                               Tacos                    1.0
# 904                               Tacos                    1.0
# 812                               Tacos                    0.0
# 842                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 122            Freshman in College                       Morning Person
# 72             Freshman in College                         Night Person
# 637                 Not a Freshman                         Night Person
# 861                 Not a Freshman                         Night Person
# 35                  Not a Freshman                         Night Person
# ..                             ...                                  ...
# 132            Freshman in College                         Night Person
# 787                 Not a Freshman                       Morning Person
# 904            Freshman in College                       Morning Person
# 812                 Not a Freshman                         Night Person
# 842                 Not a Freshman                       Morning Person
#
#     Are you a morning or an afternoon person?  \
# 122                            Morning Person
# 72                           Afternoon Person
# 637                          Afternoon Person
# 861                          Afternoon Person
# 35                           Afternoon Person
# ..                                        ...
# 132                          Afternoon Person
# 787                            Morning Person
# 904                            Morning Person
# 812                          Afternoon Person
# 842                            Morning Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 122                                         Illinois  ...
# 72                                          Illinois  ...
# 637                                         Illinois  ...
# 861                                         Illinois  ...
# 35                                          Illinois  ...
# ..                                               ...  ...
# 132                                     Out-of-state  ...
# 787                                     Out-of-state  ...
# 904                                         Illinois  ...
# 812                                         Illinois  ...
# 842                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 122                                                Y31
# 72                                                 Y23
# 637                                                Y02
# 861                                                Y34
# 35                                                 Y11
# ..                                                 ...
# 132                                                Y34
# 787                                                Y23
# 904                                                Y20
# 812                                                Y13
# 842                                           Y05, Y13
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 122                                           Moderate
# 72                                                Mild
# 637                                               Mild
# 861                                                NaN
# 35                                              strong
# ..                                                 ...
# 132                                           Moderate
# 787                                             Strong
# 904                                             Strong
# 812                                             Strong
# 842                                           Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 122                                            iSchool
# 72                                                Gies
# 637                                       Data Science
# 861                                                NaN
# 35                                          statistics
# ..                                                 ...
# 132                                               Gies
# 787                                                LAS
# 904                                                LAS
# 812                                                AHS
# 842                                                LAS
#
#     What do you think is the hardest major at UIUC?  \
# 122                                              CS
# 72                                      Engineering
# 637                                              CS
# 861                                             NaN
# 35                           electrical engineering
# ..                                              ...
# 132                          Aerospace engineering
# 787                                Computer Science
# 904                            Computer Engineering
# 812                                Computer Science
# 842                                         Physics
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 122                                   Pop                           Surfaces
# 72                Heavy Metal and Dubstep                      Sullivan King
# 637                                   Rap                           Zack Fox
# 861                                   NaN                                NaN
# 35                                    pop                        Post Malone
# ..                                    ...                                ...
# 132                                   Pop                              Vinyl
# 787                               Hip hop                             Halsey
# 904                                   Pop                            Anirudh
# 812                                   Rap                           Babytron
# 842                                   Pop                       Taylor Swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 122                                YouTube                       Innie!
# 72                                 Discord                    I don’t.
# 637                              Instagram                         INI!
# 861                                    NaN                          NaN
# 35                               instagram                          INI
# ..                                     ...                          ...
# 132                              Instagram                        I-N-I
# 787                              Instagram                        I-N-I
# 904                              Instagram                          INI
# 812                                Twitter                        I-N-I
# 842                                Twitter                       I-N-I!
#
#     What is your favorite game to play (either video game or IRL)?  \
# 122                                          Minecraft
# 72                                              Roblox
# 637                                         Basketball
# 861                                                NaN
# 35                                          smash bros
# ..                                                 ...
# 132                                           Napolean
# 787                                          Homescape
# 904                                              Chess
# 812                                         Pickleball
# 842                                              Taboo
#
#     What is your dream vacation location?
# 122                                Hawaii
# 72                                   Home
# 637                            California
# 861                                   NaN
# 35                                   city
# ..                                    ...
# 132                                 Japan
# 787                                Greece
# 904                                Alaska
# 812                                Hawaii
# 842                             Barcelona
#
# [476 rows x 180 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd. concat( [df1_control, df2_control])
control
# Out:
#          Name Section Does your NetID ending with odd number or even number?  \
# 5        Sens     Y30                     NetID ends with an even number
# 10    Aaliyah     Y13                     NetID ends with an even number
# 12       Ryan     Y30                     NetID ends with an even number
# 19     Lauren     Y03                     NetID ends with an even number
# 27     Zikora     Y31                      NetID ends with an odd number
# ..        ...     ...                                                ...
# 953     Laura     Y28                     NetID ends with an even number
# 954     Junyu  \t Y36                      NetID ends with an odd number
# 955  lijiajin     Y01                      NetID ends with an odd number
# 956   Fabian      Y11                      NetID ends with an odd number
# 959      Zoe      Y19                     NetID ends with an even number
#
#     If I flipped a coin, do you think it would it land on heads or tails?  \
# 5                                                Heads
# 10                                               Heads
# 12                                               Heads
# 19                                               Heads
# 27                                               Tails
# ..                                                 ...
# 953                                              Heads
# 954                                              Heads
# 955                                              Heads
# 956                                              Tails
# 959                                              Heads
#
#     Do you like to eat tacos or donuts?  Pick a Number: 0 or 1  \
# 5                                 Tacos                    1.0
# 10                               Donuts                    1.0
# 12                               Donuts                    0.0
# 19                                Tacos                    0.0
# 27                                  NaN                    1.0
# ..                                  ...                    ...
# 953                              Donuts                    0.0
# 954                               Tacos                    1.0
# 955                              Donuts                    0.0
# 956                               Tacos                    0.0
# 959                               Tacos                    1.0
#
#     Are you a freshman in college? Are you a morning or a night person?  \
# 5              Freshman in College                         Night Person
# 10             Freshman in College                         Night Person
# 12             Freshman in College                         Night Person
# 19                  Not a Freshman                         Night Person
# 27                  Not a Freshman                                  NaN
# ..                             ...                                  ...
# 953            Freshman in College                         Night Person
# 954            Freshman in College                         Night Person
# 955                 Not a Freshman                         Night Person
# 956                 Not a Freshman                         Night Person
# 959            Freshman in College                         Night Person
#
#     Are you a morning or an afternoon person?  \
# 5                              Morning Person
# 10                           Afternoon Person
# 12                           Afternoon Person
# 19                             Morning Person
# 27                                        NaN
# ..                                        ...
# 953                          Afternoon Person
# 954                          Afternoon Person
# 955                            Morning Person
# 956                          Afternoon Person
# 959                          Afternoon Person
#
#     Are you a student from Illinois or out-of-state?  ...  \
# 5                                           Illinois  ...
# 10                                          Illinois  ...
# 12                                          Illinois  ...
# 19                                          Illinois  ...
# 27                                               NaN  ...
# ..                                               ...  ...
# 953                                     Out-of-state  ...
# 954                                     Out-of-state  ...
# 955                                     Out-of-state  ...
# 956                                         Illinois  ...
# 959                                         Illinois  ...
#
#     What lab section are you enrolled in? (Use the three-letter code that starts with a "Y", like "Y42".)  \
# 5                                                  Y30
# 10                                                 Y13
# 12                                                 Y30
# 19                                                 Y03
# 27                                                 Y31
# ..                                                 ...
# 953                                                Y28
# 954                                             \t Y36
# 955                                                Y01
# 956                                                Y11
# 959                                                Y19
#
#     The level of spiciness you're comfortable with (None, mild, moderate, strong, extreme)?  \
# 5                                             Moderate
# 10                                             Extreme
# 12                                            Moderate
# 19                                             Strong
# 27                                             Extreme
# ..                                                 ...
# 953                                             Strong
# 954                                             strong
# 955                                             strong
# 956                                           Extreme
# 959                                          Moderate
#
#     What college is your intended major in?  (This is where you hope to end up, not necessarily your current major.)  \
# 5                                     Grainger and LAS
# 10                                             iSchool
# 12                                                 LAS
# 19                                                 LAS
# 27                                            Grainger
# ..                                                 ...
# 953                                               Gies
# 954                               information science
# 955                                                 cs
# 956                                                 IS
# 959                              School of Information
#
#     What do you think is the hardest major at UIUC?  \
# 5                                               ECE
# 10                                 Computer Science
# 12                                          Physics
# 19                                     Engineering
# 27                                          ECE 374
# ..                                              ...
# 953                                    Engineering
# 954                                              CS
# 955                                              cs
# 956                               Computer science
# 959                          Molecular engineering
#
#     What genre of music do you listen to? Who is your favorite music artist?  \
# 5                                Shoegaze                        Fiona Apple
# 10                                    Pop                       Taylor Swift
# 12                                   Rock               Two Door Cinema Club
# 19                                    All                                N/a
# 27                                   Rnb                         Jaden Smith
# ..                                    ...                                ...
# 953                                   Pop                         Eason Chen
# 954                                Hiphop                Tyler, The Creator
# 955                                   sad                           Lana Ray
# 956                                   Rap                              Drake
# 959   Everything (pop, R&B, rap, country)                      Taylor Swift
#
#     What's your favorite social media app? How do you respond to I-L-L?  \
# 5                                  Twitter                        I-N-I
# 10                                  TikTok                          INI
# 12                                 youtube                  **silence**
# 19                                 Tik Tok                        I-N-I
# 27                                  Tiktok                         Ini
# ..                                     ...                          ...
# 953                              Instagram                        I-N-I
# 954                                    Ins                         good
# 955                                    ins                        I-N-N
# 956                                      X                        I-N-I
# 959                                Tiktok                        I-N-I!
#
#     What is your favorite game to play (either video game or IRL)?  \
# 5                                            Fall Guys
# 10                                    Capture the Flag
# 12                                          Overcooked
# 19                                                 N/a
# 27                                       Forza Horizon
# ..                                                 ...
# 953                                               2048
# 954                                             Soccer
# 955                                           valorant
# 956                                          Valorant
# 959                                   Street Fighters
#
#     What is your dream vacation location?
# 5                                      PR
# 10                                  Spain
# 12              Grand Teton National Park
# 19                                  Japan
# 27                                 Europe
# ..                                    ...
# 953                                europe
# 954                          Sanya, China
# 955                               finland
# 956                                Greece
# 959                               Greece
#
# [477 rows x 180 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# *(✏️ Edit this cell to replace this text wth your answer. ✏️)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
